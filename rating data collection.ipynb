obiles&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_2_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=mobiles%7CMobiles&requestId=8853b559-37dd-489a-a8b5-51f5a20b2c0d&page=21'

#lets open the webpage through web driver
driver.get(url+url1+url2+url3+url4+url5+url6+url7+url8+url9+url10+url11+url12+url13+url14+url15+url16+url17+url18+url19+url20)

# %%
rating=[]
mobile=[]

# %%
brand=driver.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand:
    title5=i.text
    mobile.append(title5)
mobile[0:4] 
brand1=driver.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand1:
    title92=i.text
    mobile.append(title92)
mobile[0:4]
# Out:
# ['realme C25 (Watery Blue, 64 GB)',
#  'POCO M2 Reloaded (Mostly Blue, 64 GB)',
#  'realme 8 5G (Supersonic Blue, 64 GB)',
#  'REDMI Note 9 (Pebble Grey, 64 GB)']

# %%
brand2=driver.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand2:
    title82=i.text
    mobile.append(title82)
mobile[0:4] 
brand3=driver.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand3:
    title72=i.text
    mobile.append(title72)
mobile[0:4] 
brand4=driver.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand4:
    title62=i.text
    mobile.append(title62)
mobile[0:4] 
brand5=driver.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand5:
    title52=i.text
    mobile.append(title52)
mobile[0:4] 
brand6=driver.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand6:
    title42=i.text
    mobile.append(title42)
mobile[0:4] 
brand7=driver.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand7:
    title32=i.text
    mobile.append(title32)
mobile[0:4] 
brand8=driver.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand8:
    title31=i.text
    mobile.append(title31)
mobile[0:4] 
brand9=driver.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand9:
    title3=i.text
    mobile.append(title3)
mobile[0:4] 
brand10=driver.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand10:
    title29=i.text
    mobile.append(title29)
mobile[0:4] 
brand11=driver.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand11:
    title28=i.text
    mobile.append(title28)
mobile[0:4] 
brand12=driver.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand12:
    title27=i.text
    mobile.append(title27)
mobile[0:4] 
brand13=driver.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand13:
    title26=i.text
    mobile.append(title26)
mobile[0:4] 
brand14=driver.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand14:
    title25=i.text
    mobile.append(title25)
mobile[0:4] 
brand15=driver.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand15:
    title24=i.text
    mobile.append(title24)
mobile[0:4] 
brand16=driver.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand16:
    title23=i.text
    mobile.append(title23)
mobile[0:4] 
brand17=driver.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand17:
    title1=i.text
    mobile.append(title1)
mobile[0:4] 
brand18=driver.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand18:
    title22=i.text
    mobile.append(title22)
mobile[0:4] 
brand19=driver.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand19:
    title2=i.text
    mobile.append(title2)
mobile[0:4]
# Out:
# ['realme C25 (Watery Blue, 64 GB)',
#  'POCO M2 Reloaded (Mostly Blue, 64 GB)',
#  'realme 8 5G (Supersonic Blue, 64 GB)',
#  'REDMI Note 9 (Pebble Grey, 64 GB)']

# %%
rev=driver.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev:
    title3=i.text
    rating.append(title3)
rating[0:4]
rev1=driver.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev1:
    title1=i.text
    rating.append(title1)
rating[0:4]
rev2=driver.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev2:
    title2=i.text
    rating.append(title2)
rating[0:4]
rev3=driver.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev3:
    title0=i.text
    rating.append(title0)
rating[0:4]
rev4=driver.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev4:
    title4=i.text
    rating.append(title4)
rating[0:4]
rev5=driver.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev5:
    title5=i.text
    rating.append(title5)
rating[0:4]
rev6=driver.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev6:
    title6=i.text
    rating.append(title6)
rating[0:4]
rev7=driver.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev7:
    title7=i.text
    rating.append(title7)
rating[0:4]
rev8=driver.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev8:
    title8=i.text
    rating.append(title8)
rating[0:4]
rev9=driver.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev9:
    title9=i.text
    rating.append(title9)
rating[0:4]
rev10=driver.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev10:
    title31=i.text
    rating.append(title31)
rating[0:4]
rev11=driver.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev11:
    title32=i.text
    rating.append(title32)
rating[0:4]
rev12=driver.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev12:
    title33=i.text
    rating.append(title33)
rating[0:4]
rev13=driver.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev13:
    title34=i.text
    rating.append(title34)
rating[0:4]
rev14=driver.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev14:
    title35=i.text
    rating.append(title35)
rating[0:4]
rev15=driver.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev15:
    title36=i.text
    rating.append(title36)
rating[0:4]
rev16=driver.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev16:
    title37=i.text
    rating.append(title37)
rating[0:4]
rev17=driver.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev17:
    title38=i.text
    rating.append(title38)
rating[0:4]
rev18=driver.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev18:
    title39=i.text
    rating.append(title39)
rating[0:4]
rev19=driver.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev19:
    title311=i.text
    rating.append(title311)
rating[0:4]
# Out:
# ['4.419,855 Ratings & 852 Reviews',
#  '4.45,266 Ratings & 360 Reviews',
#  '4.39,791 Ratings & 735 Reviews',
#  '4.344,239 Ratings & 3,225 Reviews']

# %%
print(len(mobile))
# Out:
# 480

# %%
phone=pd.DataFrame({})
phone['mobiles']=mobile[0:480]
phone['review&rating']=rating[0:480]

# %%
phone
# Out:
#                                     mobiles  \
# 0           realme C25 (Watery Blue, 64 GB)
# 1     POCO M2 Reloaded (Mostly Blue, 64 GB)
# 2      realme 8 5G (Supersonic Blue, 64 GB)
# 3         REDMI Note 9 (Pebble Grey, 64 GB)
# 4          realme C25 (Watery Grey, 128 GB)
# ..                                      ...
# 475  MOTOROLA E7 Power (Tahiti Blue, 64 GB)
# 476   realme 8 5G (Supersonic Blue, 128 GB)
# 477      REDMI Note 9 (Arctic White, 64 GB)
# 478                       Nokia 105 SS 2021
# 479       REDMI 9 Prime (Mint Green, 64 GB)
#
#                            review&rating
# 0        4.419,855 Ratings & 852 Reviews
# 1         4.45,266 Ratings & 360 Reviews
# 2         4.39,791 Ratings & 735 Reviews
# 3      4.344,239 Ratings & 3,225 Reviews
# 4        4.419,855 Ratings & 852 Reviews
# ..                                   ...
# 475    4.123,899 Ratings & 2,173 Reviews
# 476       4.39,791 Ratings & 735 Reviews
# 477    4.344,239 Ratings & 3,225 Reviews
# ...

# %%
phone.to_csv("mobiles2.csv")

# %%
#lets first connect to the web driver
driver1=webdriver.Chrome(r"C://chromedriver.exe")

# %%
driver1.get('https://www.flipkart.com/')

url='https://www.flipkart.com/search?q=laptop&sid=6bo%2Cb5g&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_1_na_na_ps&otracker1=AS_QueryStore_OrganicAutoSuggest_1_1_na_na_ps&as-pos=1&as-type=RECENT&suggestionId=laptop%7CLaptops&requestId=d508a5c1-9e49-443b-815a-6d51a2d01ee3&as-searchtext=l'
url1='https://www.flipkart.com/search?q=laptop&sid=6bo%2Cb5g&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_1_na_na_ps&otracker1=AS_QueryStore_OrganicAutoSuggest_1_1_na_na_ps&as-pos=1&as-type=RECENT&suggestionId=laptop%7CLaptops&requestId=d508a5c1-9e49-443b-815a-6d51a2d01ee3&as-searchtext=l&page=2'
url2='https://www.flipkart.com/search?q=laptop&sid=6bo%2Cb5g&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_1_na_na_ps&otracker1=AS_QueryStore_OrganicAutoSuggest_1_1_na_na_ps&as-pos=1&as-type=RECENT&suggestionId=laptop%7CLaptops&requestId=d508a5c1-9e49-443b-815a-6d51a2d01ee3&as-searchtext=l&page=3'
url3='https://www.flipkart.com/search?q=laptop&sid=6bo%2Cb5g&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_1_na_na_ps&otracker1=AS_QueryStore_OrganicAutoSuggest
sid=6bo%2Cb5g&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_1_na_na_ps&otracker1=AS_QueryStore_OrganicAutoSuggest_1_1_na_na_ps&as-pos=1&as-type=RECENT&suggestionId=laptop%7CLaptops&requestId=d508a5c1-9e49-443b-815a-6d51a2d01ee3&as-searchtext=l&page=18'
url18='https://www.flipkart.com/search?q=laptop&sid=6bo%2Cb5g&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_1_na_na_ps&otracker1=AS_QueryStore_OrganicAutoSuggest_1_1_na_na_ps&as-pos=1&as-type=RECENT&suggestionId=laptop%7CLaptops&requestId=d508a5c1-9e49-443b-815a-6d51a2d01ee3&as-searchtext=l&page=19'
url19='https://www.flipkart.com/search?q=laptop&sid=6bo%2Cb5g&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_1_na_na_ps&otracker1=AS_QueryStore_OrganicAutoSuggest_1_1_na_na_ps&as-pos=1&as-type=RECENT&suggestionId=laptop%7CLaptops&requestId=d508a5c1-9e49-443b-815a-6d51a2d01ee3&as-searchtext=l&page=20'


#lets open the webpage through web driver
driver1.get(url+url1+url2+url3+url4+url5+url6+url7+url8+url9+url10+url11+url12+url13+url14+url15+url16+url17+url18+url19)

# %%
rating=[]
mobile=[]

# %%
brand=driver1.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand:
    title5=i.text
    mobile.append(title5)
mobile[0:4] 
brand1=driver1.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand1:
    title92=i.text
    mobile.append(title92)
mobile[0:4] 
brand2=driver1.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand2:
    title82=i.text
    mobile.append(title82)
mobile[0:4] 
brand3=driver1.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand3:
    title72=i.text
    mobile.append(title72)
mobile[0:4] 
brand4=driver1.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand4:
    title62=i.text
    mobile.append(title62)
mobile[0:4] 
brand5=driver1.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand5:
    title52=i.text
    mobile.append(title52)
mobile[0:4] 
brand6=driver1.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand6:
    title42=i.text
    mobile.append(title42)
mobile[0:4] 
brand7=driver1.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand7:
    title32=i.text
    mobile.append(title32)
mobile[0:4] 
brand8=driver1.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand8:
    title31=i.text
    mobile.append(title31)
mobile[0:4] 
brand9=driver1.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand9:
    title3=i.text
    mobile.append(title3)
mobile[0:4] 
brand10=driver1.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand10:
    title29=i.text
    mobile.append(title29)
mobile[0:4] 
brand11=driver1.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand11:
    title28=i.text
    mobile.append(title28)
mobile[0:4] 
brand12=driver1.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand12:
    title27=i.text
    mobile.append(title27)
mobile[0:4] 
brand13=driver1.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand13:
    title26=i.text
    mobile.append(title26)
mobile[0:4] 
brand14=driver1.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand14:
    title25=i.text
    mobile.append(title25)
mobile[0:4] 
brand15=driver1.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand15:
    title24=i.text
    mobile.append(title24)
mobile[0:4] 
brand16=driver1.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand16:
    title23=i.text
    mobile.append(title23)
mobile[0:4] 
brand17=driver1.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand17:
    title1=i.text
    mobile.append(title1)
mobile[0:4] 
brand18=driver1.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand18:
    title22=i.text
    mobile.append(title22)
mobile[0:4] 
brand19=driver1.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand19:
    title2=i.text
    mobile.append(title2)
mobile[0:4]
# Out:
# ['HP 14s Core i5 11th Gen - (8 GB/512 GB SSD/Windows 10 Home) 14s- DQ2535TU Thin and Light Laptop',
#  'MSI GF63 Thin Core i5 9th Gen - (8 GB/512 GB SSD/Windows 10 Home/4 GB Graphics/NVIDIA GeForce GTX 1650...',
#  'HP Pavilion x360 Core i3 11th Gen - (8 GB/256 GB SSD/Windows 10 Home) 14-dw1036TU 2 in 1 Laptop',
#  'Lenovo IdeaPad Flex 5 Ryzen 7 Octa Core 5700U - (16 GB/512 GB SSD/Windows 10 Home) 14ALC05 2 in 1 Lapt...']

# %%
rev=driver1.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev:
    title3=i.text
    rating.append(title3)
rating[0:4]
rev1=driver1.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev1:
    title1=i.text
    rating.append(title1)
rating[0:4]
rev2=driver1.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev2:
    title2=i.text
    rating.append(title2)
rating[0:4]
rev3=driver1.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev3:
    title0=i.text
    rating.append(title0)
rating[0:4]
rev4=driver1.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev4:
    title4=i.text
    rating.append(title4)
rating[0:4]
rev5=driver1.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev5:
    title5=i.text
    rating.append(title5)
rating[0:4]
rev6=driver1.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev6:
    title6=i.text
    rating.append(title6)
rating[0:4]
rev7=driver1.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev7:
    title7=i.text
    rating.append(title7)
rating[0:4]
rev8=driver1.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev8:
    title8=i.text
    rating.append(title8)
rating[0:4]
rev9=driver1.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev9:
    title9=i.text
    rating.append(title9)
rating[0:4]
rev10=driver1.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev10:
    title31=i.text
    rating.append(title31)
rating[0:4]
rev11=driver1.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev11:
    title32=i.text
    rating.append(title32)
rating[0:4]
rev12=driver1.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev12:
    title33=i.text
    rating.append(title33)
rating[0:4]
rev13=driver1.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev13:
    title34=i.text
    rating.append(title34)
rating[0:4]
rev14=driver1.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev14:
    title35=i.text
    rating.append(title35)
rating[0:4]
rev15=driver1.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev15:
    title36=i.text
    rating.append(title36)
rating[0:4]
rev16=driver1.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev16:
    title37=i.text
    rating.append(title37)
rating[0:4]
rev17=driver1.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev17:
    title38=i.text
    rating.append(title38)
rating[0:4]
rev18=driver1.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev18:
    title39=i.text
    rating.append(title39)
rating[0:4]
rev19=driver1.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev19:
    title311=i.text
    rating.append(title311)
rating[0:4]
# Out:
# ['4.3240 Ratings & 18 Reviews',
#  '4.4712 Ratings & 97 Reviews',
#  '4.4271 Ratings & 27 Reviews',
#  '4.73 Ratings & 0 Reviews']

# %%
print(len(mobile))
# Out:
# 480

# %%
laptop=pd.DataFrame({})
laptop['lappi']=mobile[0:480]
laptop['review&rating']=rating[0:480]

# %%
laptop
# Out:
#                                                  lappi  \
# 0    HP 14s Core i5 11th Gen - (8 GB/512 GB SSD/Win...
# 1    MSI GF63 Thin Core i5 9th Gen - (8 GB/512 GB S...
# 2    HP Pavilion x360 Core i3 11th Gen - (8 GB/256 ...
# 3    Lenovo IdeaPad Flex 5 Ryzen 7 Octa Core 5700U ...
# 4    Lenovo Ideapad S145 Ryzen 3 Dual Core 3200U - ...
# ..                                                 ...
# 475  ASUS Core i3 10th Gen - (4 GB/512 GB SSD/Windo...
# 476  HP 15s Core i3 11th Gen - (8 GB/1 TB HDD/Windo...
# 477  HP Pavilion Core i5 11th Gen - (16 GB/512 GB S...
# 478  HP Pavilion Gaming Ryzen 5 Quad Core 3550H - (...
# 479  Lenovo Core i3 10th Gen - (4 GB/1 TB HDD/Windo...
#
#                       review&rating
# 0       4.3240 Ratings & 18 Reviews
# 1       4.4712 Ratings & 97 Reviews
# 2       4.4271 Ratings & 27 Reviews
# 3          4.73 Ratings & 0 Reviews
# 4    3.95,082 Ratings & 749 Reviews
# ..                              ...
# 475  4.31,727 Ratings & 264 Reviews
# ...

# %%
laptop.to_csv("lappi.csv")

# %%
#lets first connect to the web driver
driver2=webdriver.Chrome(r"C://chromedriver.exe")

# %%
driver2.get('https://www.flipkart.com/')

url='https://www.flipkart.com/search?q=mobiles&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore
obiles&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_HistoryAutoSuggest_1_2_na_na_na&otracker1=AS_QueryStore_HistoryAutoSuggest_1_2_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=mobiles%7CMobiles&requestId=6da3f59c-9560-4b20-ac85-8745c24757a0&as-searchtext=mo&page=38'
url17='https://www.flipkart.com/search?q=mobiles&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_HistoryAutoSuggest_1_2_na_na_na&otracker1=AS_QueryStore_HistoryAutoSuggest_1_2_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=mobiles%7CMobiles&requestId=6da3f59c-9560-4b20-ac85-8745c24757a0&as-searchtext=mo&page=39'
url18='https://www.flipkart.com/search?q=mobiles&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_HistoryAutoSuggest_1_2_na_na_na&otracker1=AS_QueryStore_HistoryAutoSuggest_1_2_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=mobiles%7CMobiles&requestId=6da3f59c-9560-4b20-ac85-8745c24757a0&as-searchtext=mo&page=40'
url19='https://www.flipkart.com/search?q=mobiles&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_HistoryAutoSuggest_1_2_na_na_na&otracker1=AS_QueryStore_HistoryAutoSuggest_1_2_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=mobiles%7CMobiles&requestId=6da3f59c-9560-4b20-ac85-8745c24757a0&as-searchtext=mo&page=41'
url20='https://www.flipkart.com/search?q=mobiles&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_HistoryAutoSuggest_1_2_na_na_na&otracker1=AS_QueryStore_HistoryAutoSuggest_1_2_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=mobiles%7CMobiles&requestId=6da3f59c-9560-4b20-ac85-8745c24757a0&as-searchtext=mo&page=42'
url21='https://www.flipkart.com/search?q=mobiles&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_HistoryAutoSuggest_1_2_na_na_na&otracker1=AS_QueryStore_HistoryAutoSuggest_1_2_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=mobiles%7CMobiles&requestId=6da3f59c-9560-4b20-ac85-8745c24757a0&as-searchtext=mo&page=43'
url22='https://www.flipkart.com/search?q=mobiles&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_HistoryAutoSuggest_1_2_na_na_na&otracker1=AS_QueryStore_HistoryAutoSuggest_1_2_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=mobiles%7CMobiles&requestId=6da3f59c-9560-4b20-ac85-8745c24757a0&as-searchtext=mo&page=44'
url23='https://www.flipkart.com/search?q=mobiles&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_HistoryAutoSuggest_1_2_na_na_na&otracker1=AS_QueryStore_HistoryAutoSuggest_1_2_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=mobiles%7CMobiles&requestId=6da3f59c-9560-4b20-ac85-8745c24757a0&as-searchtext=mo&page=45'
url24='https://www.flipkart.com/search?q=mobiles&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_HistoryAutoSuggest_1_2_na_na_na&otracker1=AS_QueryStore_HistoryAutoSuggest_1_2_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=mobiles%7CMobiles&requestId=6da3f59c-9560-4b20-ac85-8745c24757a0&as-searchtext=mo&page=46'

driver2.get(url+url1+url2+url3+url4+url5+url6+url7+url8+url9+url10+url11+url12+url13+url14+url15+url16+url17+url18+url19+url20+url21+url22+url23+url24)

# %%
rating=[]
mobile=[]

# %%
brand=driver2.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand:
    title5=i.text
    mobile.append(title5)
mobile[0:4] 
brand1=driver2.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand1:
    title92=i.text
    mobile.append(title92)
mobile[0:4] 
brand2=driver2.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand2:
    title82=i.text
    mobile.append(title82)
mobile[0:4] 
brand3=driver2.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand3:
    title72=i.text
    mobile.append(title72)
mobile[0:4] 
brand4=driver2.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand4:
    title62=i.text
    mobile.append(title62)
mobile[0:4] 
brand5=driver2.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand5:
    title52=i.text
    mobile.append(title52)
mobile[0:4] 
brand6=driver2.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand6:
    title42=i.text
    mobile.append(title42)
mobile[0:4] 
brand7=driver2.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand7:
    title32=i.text
    mobile.append(title32)
mobile[0:4] 
brand8=driver2.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand8:
    title31=i.text
    mobile.append(title31)
mobile[0:4] 
brand9=driver2.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand9:
    title3=i.text
    mobile.append(title3)
mobile[0:4] 
brand10=driver2.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand10:
    title29=i.text
    mobile.append(title29)
mobile[0:4] 
brand11=driver2.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand11:
    title28=i.text
    mobile.append(title28)
mobile[0:4] 
brand12=driver2.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand12:
    title27=i.text
    mobile.append(title27)
mobile[0:4] 
brand13=driver2.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand13:
    title26=i.text
    mobile.append(title26)
mobile[0:4] 
brand14=driver2.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand14:
    title25=i.text
    mobile.append(title25)
mobile[0:4] 
brand15=driver2.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand15:
    title24=i.text
    mobile.append(title24)
mobile[0:4] 
brand16=driver2.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand16:
    title23=i.text
    mobile.append(title23)
mobile[0:4] 
brand17=driver2.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand17:
    title1=i.text
    mobile.append(title1)
mobile[0:4] 
brand18=driver2.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand18:
    title22=i.text
    mobile.append(title22)
mobile[0:4] 
brand19=driver2.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand19:
    title2=i.text
    mobile.append(title2)
mobile[0:4]
# Out:
# ['realme 7 (Mist White, 128 GB)',
#  'SAMSUNG Galaxy M02 (Red, 32 GB)',
#  'KARBONN KX26i',
#  'Itel Magic2 Max']

# %%
rev=driver2.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev:
    title3=i.text
    rating.append(title3)
rating[0:4]
rev1=driver2.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev1:
    title1=i.text
    rating.append(title1)
rating[0:4]
rev2=driver2.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev2:
    title2=i.text
    rating.append(title2)
rating[0:4]
rev3=driver2.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev3:
    title0=i.text
    rating.append(title0)
rating[0:4]
rev4=driver2.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev4:
    title4=i.text
    rating.append(title4)
rating[0:4]
rev5=driver2.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev5:
    title5=i.text
    rating.append(title5)
rating[0:4]
rev6=driver2.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev6:
    title6=i.text
    rating.append(title6)
rating[0:4]
rev7=driver2.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev7:
    title7=i.text
    rating.append(title7)
rating[0:4]
rev8=driver2.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev8:
    title8=i.text
    rating.append(title8)
rating[0:4]
rev9=driver2.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev9:
    title9=i.text
    rating.append(title9)
rating[0:4]
rev10=driver2.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev10:
    title31=i.text
    rating.append(title31)
rating[0:4]
rev11=driver2.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev11:
    title32=i.text
    rating.append(title32)
rating[0:4]
rev12=driver2.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev12:
    title33=i.text
    rating.append(title33)
rating[0:4]
rev13=driver2.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev13:
    title34=i.text
    rating.append(title34)
rating[0:4]
rev14=driver2.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev14:
    title35=i.text
    rating.append(title35)
rating[0:4]
rev15=driver2.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev15:
    title36=i.text
    rating.append(title36)
rating[0:4]
rev16=driver2.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev16:
    title37=i.text
    rating.append(title37)
rating[0:4]
rev17=driver2.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev17:
    title38=i.text
    rating.append(title38)
rating[0:4]
rev18=driver2.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev18:
    title39=i.text
    rating.append(title39)
rating[0:4]
rev19=driver2.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev19:
    title311=i.text
    rating.append(title311)
rating[0:4]
# Out:
# ['4.381,617 Ratings & 7,918 Reviews',
#  '4627 Ratings & 61 Reviews',
#  '3.9275 Ratings & 24 Reviews',
#  '4.2270 Ratings & 22 Reviews']

# %%
print(len(mobile))
# Out:
# 480

# %%
phone1=pd.DataFrame({})
phone1['mobiles']=mobile[0:480]
phone1['review&rating']=rating[0:480]

# %%
phone1
# Out:
#                              mobiles                      review&rating
# 0      realme 7 (Mist White, 128 GB)  4.381,617 Ratings & 7,918 Reviews
# 1    SAMSUNG Galaxy M02 (Red, 32 GB)          4627 Ratings & 61 Reviews
# 2                      KARBONN KX26i        3.9275 Ratings & 24 Reviews
# 3                    Itel Magic2 Max        4.2270 Ratings & 22 Reviews
# 4      Nokia C3 (Nordic Blue, 16 GB)      3.91,196 Ratings & 97 Reviews
# ..                               ...                                ...
# 475                 GREENBERRI G5000  4.687,693 Ratings & 7,508 Reviews
# 476                 GREENBERRI G5000        4.5452 Ratings & 76 Reviews
# 477                       I Kall K50     4.49,487 Ratings & 639 Reviews
# 478  APPLE iPhone 12 (White, 128 GB)        3.9465 Ratings & 34 Reviews
# 479                 KARBONN K140 Pop     4.41,367 Ratings & 100 Reviews
#
# [480 rows x 2 columns]

# %%
phone1.to_csv("mobiles1.csv")

# %%
#lets first connect to the web driver
driver3=webdriver.Chrome(r"C://chromedriver.exe")

# %%
driver3.get('https://www.flipkart.com/')


url='https://www.flipkart.com/search?q=tv&as=on&as-show=on&otracker=AS_Query_HistoryAutoSuggest_1_2_na_na_na&otracker1=AS_Query_HistoryAutoSuggest_1_2_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=tv&requestId=5d61783b-8352-460d-aa9c-abf0b69b1c9e&as-searchtext=tv'
url1='https://www.flipkart.com/search?q=tv&as=on&as-show=on&otracker=AS_Query_HistoryAutoSuggest_1_2_na_na_na&otracker1=AS_Query_HistoryAutoSuggest_1_2_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=tv&requestId=5d61783b-8352-460d-aa9c-abf0b69b1c9e&as-searchtext=tv&page=2'
url2='https://www.flipkart.com/search?q=tv&as=on&as-show=on&otracker=AS_Query_HistoryAutoSuggest_1_2_na_na_na&otracker1=AS_Query_HistoryAutoSuggest_1_2_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=tv&requestId=5d61783b-8352-460d-aa9c-abf0b69b1c9e&as-searchtext=tv&page=3'
url3='https://www.flipkart.com/search?q=tv&as=on&as-show=on&otracker=AS_Query_HistoryAutoSuggest_1_2_na_na_na&otracker1=AS_Query_HistoryAutoSuggest_1_2_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=tv&requestId=5d61783b-8352-460d-aa9c-abf0b69b1c9e&as-searchtext=tv&page=4'
url4='https://www.flipkart.com/search?q=tv&as=on&as-show=on&otracker=AS_Query_HistoryAutoSuggest_1_2_na_na_na&otracker1=AS_Query_HistoryAutoSuggest_1_2_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=tv&requestId=5d61783b-8352-460d-aa9c-abf0b69b1c9e&as-searchtext=tv&page=5'
url5='https://www.flipkart.com/search?q=tv&as=on&as-show=on&otracker=AS_Query_HistoryAutoSuggest_1_2_na_na_na&otracker1=AS_Query_HistoryAutoSuggest_1_2_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=tv&requestId=5d61783b-8352-460d-aa9c-abf0b69b1c9e&as-searchtext=tv&page=6'
url6='https://www.flipkart.com/search?q=tv&as=on&as-show=on&otracker=AS_Query_HistoryAutoSuggest_1_2_na_na_na&otracker1=AS_Query_HistoryAutoSuggest_1_2_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=tv&requestId=5d61783b-8352-460d-aa9c-abf0b69b1c9e&as-searchtext=tv&page=7'
url7='https://www.flipkart.com/search?q=tv&as=on&as-show=on&otracker=AS_Query_HistoryAutoSuggest_1_2_na_na_na&otracker1=AS_Query_HistoryAutoSuggest_1_2_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=tv&requestId=5d61783b-8352-460d-aa9c-abf0b69b1c9e&as-searchtext=tv&page=8'
url8='https://www.flipkart.com/search?q=tv&as=on&as-show=on&otracker=AS_Query_HistoryAutoSuggest_1_2_na_na_na&otracker1=AS_Query_HistoryAutoSuggest_1_2_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=tv&requestId=5d61783b-8352-460d-aa9c-abf0b69b1c9e&as-searchtext=tv&page=9'
url9='https://www.flipkart.com/search?q=tv&as=on&as-show=on&otracker=AS_Query_HistoryAutoSuggest_1_2_na_na_na&otracker1=AS_Query_HistoryAutoSuggest_1_2_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=tv&requestId=5d61783b-8352-460d-aa9c-abf0b69b1c9e&as-searchtext=tv&page=10'
url10='https://www.flipkart.com/search?q=tv&as=on&as-show=on&otracker=AS_Query_HistoryAutoSuggest_1_2_na_na_na&otracker1=AS_Query_HistoryAutoSuggest_1_2_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=tv&requestId=5d61783b-8352-460d-aa9c-abf0b69b1c9e&as-searchtext=tv&page=11'
url11='https://www.flipkart.com/search?q=tv&as=on&as-show=on&otracker=AS_Query_HistoryAutoSuggest_1_2_na_na_na&otracker1=AS_Query_HistoryAutoSuggest_1_2_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=tv&requestId=5d61783b-8352-460d-aa9c-abf0b69b1c9e&as-searchtext=tv&page=12'
url12='https://www.flipkart.com/search?q=tv&as=on&as-show=on&otracker=AS_Query_HistoryAutoSuggest_1_2_na_na_na&otracker1=AS_Query_HistoryAutoSuggest_1_2_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=tv&requestId=5d61783b-8352-460d-aa9c-abf0b69b1c9e&as-searchtext=tv&page=13'
url13='https://www.flipkart.com/search?q=tv&as=on&as-show=on&otracker=AS_Query_HistoryAutoSuggest_1_2_na_na_na&otracker1=AS_Query_HistoryAutoSuggest_1_2_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=tv&requestId=5d61783b-8352-460d-aa9c-abf0b69b1c9e&as-searchtext=tv&page=14'
url14='https://www.flipkart.com/search?q=tv&as=on&as-show=on&otracker=AS_Query_HistoryAutoSuggest_1_2_na_na_na&otracker1=AS_Query_HistoryAutoSuggest_1_2_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=tv&requestId=5d61783b-8352-460d-aa9c-abf0b69b1c9e&as-searchtext=tv&page=15'
url15='https://www.flipkart.com/search?q=tv&as=on&as-show=on&otracker=AS_Query_HistoryAutoSuggest_1_2_na_na_na&otracker1=AS_Query_HistoryAutoSuggest_1_2_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=tv&requestId=5d61783b-8352-460d-aa9c-abf0b69b1c9e&as-searchtext=tv&page=16'
url16='https://www.flipkart.com/search?q=tv&as=on&as-show=on&otracker=AS_Query_HistoryAutoSuggest_1_2_na_na_na&otracker1=AS_Query_HistoryAutoSuggest_1_2_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=tv&requestId=5d61783b-8352-460d-aa9c-abf0b69b1c9e&as-searchtext=tv&page=17'
url17='https://www.flipkart.com/search?q=tv&as=on&as-show=on&otracker=AS_Query_HistoryAutoSuggest_1_2_na_na_na&otracker1=AS_Query_HistoryAutoSuggest_1_2_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=tv&requestId=5d61783b-8352-460d-aa9c-abf0b69b1c9e&as-searchtext=tv&page=18'
url18='https://www.flipkart.com/search?q=tv&as=on&as-show=on&otracker=AS_Query_HistoryAutoSuggest_1_2_na_na_na&otracker1=AS_Query_HistoryAutoSuggest_1_2_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=tv&requestId=5d61783b-8352-460d-aa9c-abf0b69b1c9e&as-searchtext=tv&page=19'
url19='https://www.flipkart.com/search?q=tv&as=on&as-show=on&otracker=AS_Query_HistoryAutoSuggest_1_2_na_na_na&otracker1=AS_Query_HistoryAutoSuggest_1_2_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=tv&requestId=5d61783b-8352-460d-aa9c-abf0b69b1c9e&as-searchtext=tv&page=20'


driver3.get(url+url1+url2+url3+url4+url5+url6+url7+url8+url9+url10+url11+url12+url13+url14+url15+url16+url17+url18+url19)

# %%
rating=[]
mobile=[]

# %%
brand=driver3.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand:
    title5=i.text
    mobile.append(title5)
mobile[0:4] 
brand1=driver3.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand1:
    title92=i.text
    mobile.append(title92)
mobile[0:4] 
brand2=driver3.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand2:
    title82=i.text
    mobile.append(title82)
mobile[0:4] 
brand3=driver3.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand3:
    title72=i.text
    mobile.append(title72)
mobile[0:4] 
brand4=driver3.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand4:
    title62=i.text
    mobile.append(title62)
mobile[0:4] 
brand5=driver3.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand5:
    title52=i.text
    mobile.append(title52)
mobile[0:4] 
brand6=driver3.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand6:
    title42=i.text
    mobile.append(title42)
mobile[0:4] 
brand7=driver3.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand7:
    title32=i.text
    mobile.append(title32)
mobile[0:4] 
brand8=driver3.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand8:
    title31=i.text
    mobile.append(title31)
mobile[0:4] 
brand9=driver3.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand9:
    title3=i.text
    mobile.append(title3)
mobile[0:4] 
brand10=driver3.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand10:
    title29=i.text
    mobile.append(title29)
mobile[0:4] 
brand11=driver3.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand11:
    title28=i.text
    mobile.append(title28)
mobile[0:4] 
brand12=driver3.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand12:
    title27=i.text
    mobile.append(title27)
mobile[0:4] 
brand13=driver3.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand13:
    title26=i.text
    mobile.append(title26)
mobile[0:4] 
brand14=driver3.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand14:
    title25=i.text
    mobile.append(title25)
mobile[0:4] 
brand15=driver3.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand15:
    title24=i.text
    mobile.append(title24)
mobile[0:4] 
brand16=driver3.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand16:
    title23=i.text
    mobile.append(title23)
mobile[0:4] 
brand17=driver3.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand17:
    title1=i.text
    mobile.append(title1)
mobile[0:4] 
brand18=driver3.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand18:
    title22=i.text
    mobile.append(title22)
mobile[0:4] 
brand19=driver3.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand19:
    title2=i.text
    mobile.append(title2)
mobile[0:4]
# Out:
# ['Nokia 80 cm (32 inch) HD Ready LED Smart Android TV with Sound by Onkyo',
#  'Nokia 108 cm (43 inch) Ultra HD (4K) LED Smart Android TV with Sound by Onkyo',
#  'Thomson R9 80 cm (32 inch) HD Ready LED TV',
#  'iFFALCON by TCL 108 cm (43 inch) Ultra HD (4K) LED Smart Android TV']

# %%
rev=driver3.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev:
    title3=i.text
    rating.append(title3)
rating[0:4]
rev1=driver3.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev1:
    title1=i.text
    rating.append(title1)
rating[0:4]
rev2=driver3.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev2:
    title2=i.text
    rating.append(title2)
rating[0:4]
rev3=driver3.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev3:
    title0=i.text
    rating.append(title0)
rating[0:4]
rev4=driver3.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev4:
    title4=i.text
    rating.append(title4)
rating[0:4]
rev5=driver3.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev5:
    title5=i.text
    rating.append(title5)
rating[0:4]
rev6=driver3.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev6:
    title6=i.text
    rating.append(title6)
rating[0:4]
rev7=driver3.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev7:
    title7=i.text
    rating.append(title7)
rating[0:4]
rev8=driver3.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev8:
    title8=i.text
    rating.append(title8)
rating[0:4]
rev9=driver3.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev9:
    title9=i.text
    rating.append(title9)
rating[0:4]
rev10=driver3.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev10:
    title31=i.text
    rating.append(title31)
rating[0:4]
rev11=driver3.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev11:
    title32=i.text
    rating.append(title32)
rating[0:4]
rev12=driver3.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev12:
    title33=i.text
    rating.append(title33)
rating[0:4]
rev13=driver3.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev13:
    title34=i.text
    rating.append(title34)
rating[0:4]
rev14=driver3.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev14:
    title35=i.text
    rating.append(title35)
rating[0:4]
rev15=driver3.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev15:
    title36=i.text
    rating.append(title36)
rating[0:4]
rev16=driver3.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev16:
    title37=i.text
    rating.append(title37)
rating[0:4]
rev17=driver3.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev17:
    title38=i.text
    rating.append(title38)
rating[0:4]
rev18=driver3.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev18:
    title39=i.text
    rating.append(title39)
rating[0:4]
rev19=driver3.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev19:
    title311=i.text
    rating.append(title311)
rating[0:4]
# Out:
# ['4.312,359 Ratings & 2,221 Reviews',
#  '4.34,416 Ratings & 779 Reviews',
#  '4.241,599 Ratings & 6,597 Reviews',
#  '4.24,799 Ratings & 665 Reviews']

# %%
print(len(mobile))
# Out:
# 480

# %%
tv=pd.DataFrame({})
tv['tv']=mobile[0:480]
tv['review&rating']=rating[0:480]

# %%
tv
# Out:
#                                                     tv  \
# 0    Nokia 80 cm (32 inch) HD Ready LED Smart Andro...
# 1    Nokia 108 cm (43 inch) Ultra HD (4K) LED Smart...
# 2           Thomson R9 80 cm (32 inch) HD Ready LED TV
# 3    iFFALCON by TCL 108 cm (43 inch) Ultra HD (4K)...
# 4    realme 126 cm (50 inch) Ultra HD (4K) LED Smar...
# ..                                                 ...
# 475  SAMSUNG 80 cm (32 inch) HD Ready LED Smart TV ...
# 476  TOSHIBA U50 Series 108 cm (43 inch) Ultra HD (...
# 477  Vu Cinema TV Action Series 139 cm (55 inch) Ul...
# 478  Vu Premium 139 cm (55 inch) Ultra HD (4K) LED ...
# 479  Hisense A73F 139 cm (55 inch) Ultra HD (4K) LE...
#
#                          review&rating
# 0    4.312,359 Ratings & 2,221 Reviews
# 1       4.34,416 Ratings & 779 Reviews
# 2    4.241,599 Ratings & 6,597 Reviews
# 3       4.24,799 Ratings & 665 Reviews
# 4          4.1353 Ratings & 52 Reviews
# ..                                 ...
# ...

# %%
tv.to_csv("tv.csv")

# %%
#lets first connect to the web driver
driver4=webdriver.Chrome(r"C://chromedriver.exe")

# %%
driver4.get('https://www.flipkart.com/')


url='https://www.flipkart.com/search?q=tv&as=on&as-show=on&otracker=AS_Query_HistoryAutoSuggest_1_2_na_na_na&otracker1=AS_Query_HistoryAutoSuggest_1_2_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=tv&requestId=5d61783b-8352-460d-aa9c-abf0b69b1c9e&as-searchtext=tv&page=21'
url1='https://www.flipkart.com/search?q=tv&as=on&as-show=on&otracker=AS_Query_HistoryAutoSuggest_1_2_na_na_na&otracker1=AS_Query_HistoryAutoSuggest_1_2_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=tv&requestId=5d61783b-8352-460d-aa9c-abf0b69b1c9e&as-searchtext=tv&page=22'
url2='https://www.flipkart.com/search?q=tv&as=on&as-show=on&otracker=AS_Query_HistoryAutoSuggest_1_2_na_na_na&otracker1=AS_Query_HistoryAutoSuggest_1_2_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=tv&requestId=5d61783b-8352-460d-aa9c-abf0b69b1c9e&as-searchtext=tv&page=23'
url3='https://www.flipkart.com/search?q=tv&as=on&as-show=on&otracker=AS_Query_HistoryAutoSuggest_1_2_na_na_na&otracker1=AS_Query_HistoryAutoSuggest_1_2_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=tv&requestId=5d61783b-8352-460d-aa9c-abf0b69b1c9e&as-searchtext=tv&page=24'
url4='https://www.flipkart.com/search?q=tv&as=on&as-show=on&otracker=AS_Query_HistoryAutoSuggest_1_2_na_na_na&otracker1=AS_Query_HistoryAutoSuggest_1_2_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=tv&requestId=5d61783b-8352-460d-aa9c-abf0b69b1c9e&as-searchtext=tv&page=25'
url5='https://www.flipkart.com/search?q=tv&as=on&as-show=on&otracker=AS_Query_HistoryAutoSuggest_1_2_na_na_na&otracker1=AS_Query_HistoryAutoSuggest_1_2_na_na_na&as-pos=1&as-type=HISTORY&suggestionId
utoSuggest_1_2_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=tv&requestId=5d61783b-8352-460d-aa9c-abf0b69b1c9e&as-searchtext=tv&page=37'
url17='https://www.flipkart.com/search?q=tv&as=on&as-show=on&otracker=AS_Query_HistoryAutoSuggest_1_2_na_na_na&otracker1=AS_Query_HistoryAutoSuggest_1_2_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=tv&requestId=5d61783b-8352-460d-aa9c-abf0b69b1c9e&as-searchtext=tv&page=38'
url18='https://www.flipkart.com/search?q=tv&as=on&as-show=on&otracker=AS_Query_HistoryAutoSuggest_1_2_na_na_na&otracker1=AS_Query_HistoryAutoSuggest_1_2_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=tv&requestId=5d61783b-8352-460d-aa9c-abf0b69b1c9e&as-searchtext=tv&page=39'
url19='https://www.flipkart.com/search?q=tv&as=on&as-show=on&otracker=AS_Query_HistoryAutoSuggest_1_2_na_na_na&otracker1=AS_Query_HistoryAutoSuggest_1_2_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=tv&requestId=5d61783b-8352-460d-aa9c-abf0b69b1c9e&as-searchtext=tv&page=40'


driver4.get(url+url1+url2+url3+url4+url5+url6+url7+url8+url9+url10+url11+url12+url13+url14+url15+url16+url17+url18+url19)

# %%
rating=[]
mobile=[]

# %%
brand=driver4.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand:
    title5=i.text
    mobile.append(title5)
mobile[0:4] 
brand1=driver4.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand1:
    title92=i.text
    mobile.append(title92)
mobile[0:4] 
brand2=driver4.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand2:
    title82=i.text
    mobile.append(title82)
mobile[0:4] 
brand3=driver4.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand3:
    title72=i.text
    mobile.append(title72)
mobile[0:4] 
brand4=driver4.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand4:
    title62=i.text
    mobile.append(title62)
mobile[0:4] 
brand5=driver4.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand5:
    title52=i.text
    mobile.append(title52)
mobile[0:4] 
brand6=driver4.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand6:
    title42=i.text
    mobile.append(title42)
mobile[0:4] 
brand7=driver4.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand7:
    title32=i.text
    mobile.append(title32)
mobile[0:4] 
brand8=driver4.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand8:
    title31=i.text
    mobile.append(title31)
mobile[0:4] 
brand9=driver4.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand9:
    title3=i.text
    mobile.append(title3)
mobile[0:4] 
brand10=driver4.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand10:
    title29=i.text
    mobile.append(title29)
mobile[0:4] 
brand11=driver4.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand11:
    title28=i.text
    mobile.append(title28)
mobile[0:4] 
brand12=driver4.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand12:
    title27=i.text
    mobile.append(title27)
mobile[0:4] 
brand13=driver4.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand13:
    title26=i.text
    mobile.append(title26)
mobile[0:4] 
brand14=driver4.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand14:
    title25=i.text
    mobile.append(title25)
mobile[0:4] 
brand15=driver4.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand15:
    title24=i.text
    mobile.append(title24)
mobile[0:4] 
brand16=driver4.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand16:
    title23=i.text
    mobile.append(title23)
mobile[0:4] 
brand17=driver4.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand17:
    title1=i.text
    mobile.append(title1)
mobile[0:4] 
brand18=driver4.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand18:
    title22=i.text
    mobile.append(title22)
mobile[0:4] 
brand19=driver4.find_elements_by_xpath("//div[@class='_4rR01T']")
for i in brand19:
    title2=i.text
    mobile.append(title2)
mobile[0:4]
# Out:
# ['LG 165.1 cm (65 inch) Ultra HD (4K) LED Smart TV',
#  'SAMSUNG R5570 108 cm (43 inch) Full HD LED Smart TV',
#  'LG 123 cm (49 inch) Ultra HD (4K) LED Smart TV',
#  'SAMSUNG 80 cm (32 inch) HD Ready LED Smart TV 2020 Edition']

# %%
rev=driver4.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev:
    title3=i.text
    rating.append(title3)
rating[0:4]
rev1=driver4.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev1:
    title1=i.text
    rating.append(title1)
rating[0:4]
rev2=driver4.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev2:
    title2=i.text
    rating.append(title2)
rating[0:4]
rev3=driver4.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev3:
    title0=i.text
    rating.append(title0)
rating[0:4]
rev4=driver4.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev4:
    title4=i.text
    rating.append(title4)
rating[0:4]
rev5=driver4.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev5:
    title5=i.text
    rating.append(title5)
rating[0:4]
rev6=driver4.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev6:
    title6=i.text
    rating.append(title6)
rating[0:4]
rev7=driver4.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev7:
    title7=i.text
    rating.append(title7)
rating[0:4]
rev8=driver4.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev8:
    title8=i.text
    rating.append(title8)
rating[0:4]
rev9=driver4.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev9:
    title9=i.text
    rating.append(title9)
rating[0:4]
rev10=driver4.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev10:
    title31=i.text
    rating.append(title31)
rating[0:4]
rev11=driver4.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev11:
    title32=i.text
    rating.append(title32)
rating[0:4]
rev12=driver4.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev12:
    title33=i.text
    rating.append(title33)
rating[0:4]
rev13=driver4.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev13:
    title34=i.text
    rating.append(title34)
rating[0:4]
rev14=driver4.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev14:
    title35=i.text
    rating.append(title35)
rating[0:4]
rev15=driver4.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev15:
    title36=i.text
    rating.append(title36)
rating[0:4]
rev16=driver4.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev16:
    title37=i.text
    rating.append(title37)
rating[0:4]
rev17=driver4.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev17:
    title38=i.text
    rating.append(title38)
rating[0:4]
rev18=driver4.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev18:
    title39=i.text
    rating.append(title39)
rating[0:4]
rev19=driver4.find_elements_by_xpath("//div[@class='gUuXy-']")
for i in rev19:
    title311=i.text
    rating.append(title311)
rating[0:4]
# Out:
# ['4.69 Ratings & 1 Reviews',
#  '4.459 Ratings & 14 Reviews',
#  '4.431,685 Ratings & 2,963 Reviews',
#  '4.84 Ratings & 1 Reviews']

# %%
print(len(mobile),len(rating))
# Out:
# 480 440

# %%
tv1=pd.DataFrame({})
tv1['tv1']=mobile[0:440]
tv1['review&rating']=rating[0:440]

# %%
tv1
# Out:
#                                                    tv1  \
# 0     LG 165.1 cm (65 inch) Ultra HD (4K) LED Smart TV
# 1    SAMSUNG R5570 108 cm (43 inch) Full HD LED Sma...
# 2       LG 123 cm (49 inch) Ultra HD (4K) LED Smart TV
# 3    SAMSUNG 80 cm (32 inch) HD Ready LED Smart TV ...
# 4      LG 164 cm (65 inch) OLED Ultra HD (4K) Smart TV
# ..                                                 ...
# 435  SAMSUNG 80 cm (32 inch) HD Ready LED Smart TV ...
# 436    LG 164 cm (65 inch) OLED Ultra HD (4K) Smart TV
# 437              Haier 80 cm (32 inch) HD Ready LED TV
# 438          Blaupunkt 100 cm (40 inch) Full HD LED TV
# 439      SAMSUNG 108 cm (43 inch) Full HD LED Smart TV
#
#                          review&rating
# 0             4.69 Ratings & 1 Reviews
# 1           4.459 Ratings & 14 Reviews
# 2    4.431,685 Ratings & 2,963 Reviews
# 3             4.84 Ratings & 1 Reviews
# 4            4.640 Ratings & 6 Reviews
# ..                                 ...
# ...

# %%
tv1.to_csv("tv1.csv")

# %%
#lets first connect to the web driver
driver5=webdriver.Chrome(r"C://chromedriver.exe")

# %%
driver5.get('https://www.ebay.com/')

url='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094'
url1='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?_pgn=2'
url2='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?_pgn=3'
url3='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?_pgn=4'
url4='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=5'
url5='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=6'
url6='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=7'
url7='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=8'
url8='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=9'
url9='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=10'
url10='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=11'
url11='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=12'
url12='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=13'
url13='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=14'
url14='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=15'
url15='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=16'
url16='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=17'
url17='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=18'
url18='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=19'
url19='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=20'

driver5.get(url+url1+url2+url3+url4+url5+url6+url7+url8+url9+url10+url11+url12+url13+url14+url15+url16+url17+url18+url19)

# %%
rating=[]
mobile=[]

# %%
brand=driver5.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand:
    title5=i.text
    mobile.append(title5)
mobile[0:4] 
brand1=driver5.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand1:
    title92=i.text
    mobile.append(title92)
mobile[0:4] 
brand2=driver5.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand2:
    title82=i.text
    mobile.append(title82)
mobile[0:4] 
brand3=driver5.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand3:
    title72=i.text
    mobile.append(title72)
mobile[0:4] 
brand4=driver5.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand4:
    title62=i.text
    mobile.append(title62)
mobile[0:4] 
brand5=driver5.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand5:
    title52=i.text
    mobile.append(title52)
mobile[0:4] 
brand6=driver5.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand6:
    title42=i.text
    mobile.append(title42)
mobile[0:4] 
brand7=driver5.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand7:
    title32=i.text
    mobile.append(title32)
mobile[0:4] 
brand8=driver5.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand8:
    title31=i.text
    mobile.append(title31)
mobile[0:4] 
brand9=driver5.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand9:
    title3=i.text
    mobile.append(title3)
mobile[0:4] 
brand10=driver5.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand10:
    title29=i.text
    mobile.append(title29)
mobile[0:4] 
brand11=driver5.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand11:
    title28=i.text
    mobile.append(title28)
mobile[0:4] 
brand12=driver5.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand12:
    title27=i.text
    mobile.append(title27)
mobile[0:4] 
brand13=driver5.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand13:
    title26=i.text
    mobile.append(title26)
mobile[0:4] 
brand14=driver5.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand14:
    title25=i.text
    mobile.append(title25)
mobile[0:4] 
brand15=driver5.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand15:
    title24=i.text
    mobile.append(title24)
mobile[0:4] 
brand16=driver5.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand16:
    title23=i.text
    mobile.append(title23)
mobile[0:4] 
brand17=driver5.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand17:
    title1=i.text
    mobile.append(title1)
mobile[0:4] 
brand18=driver5.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand18:
    title22=i.text
    mobile.append(title22)
mobile[0:4] 
brand19=driver5.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand19:
    title2=i.text
    mobile.append(title2)
mobile[0:4]
# Out:
# ['4 out of 5 stars',
#  '5 out of 5 stars',
#  '5 out of 5 stars',
#  '4.5 out of 5 stars']

# %%
rev=driver5.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev:
    title3=i.text
    rating.append(title3)
rating[0:4]
rev1=driver5.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev1:
    title1=i.text
    rating.append(title1)
rating[0:4]
rev2=driver5.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev2:
    title2=i.text
    rating.append(title2)
rating[0:4]
rev3=driver5.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev3:
    title0=i.text
    rating.append(title0)
rating[0:4]
rev4=driver5.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev4:
    title4=i.text
    rating.append(title4)
rating[0:4]
rev5=driver5.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev5:
    title5=i.text
    rating.append(title5)
rating[0:4]
rev6=driver5.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev6:
    title6=i.text
    rating.append(title6)
rating[0:4]
rev7=driver5.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev7:
    title7=i.text
    rating.append(title7)
rating[0:4]
rev8=driver5.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev8:
    title8=i.text
    rating.append(title8)
rating[0:4]
rev9=driver5.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev9:
    title9=i.text
    rating.append(title9)
rating[0:4]
rev10=driver5.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev10:
    title31=i.text
    rating.append(title31)
rating[0:4]
rev11=driver5.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev11:
    title32=i.text
    rating.append(title32)
rating[0:4]
rev12=driver5.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev12:
    title33=i.text
    rating.append(title33)
rating[0:4]
rev13=driver5.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev13:
    title34=i.text
    rating.append(title34)
rating[0:4]
rev14=driver5.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev14:
    title35=i.text
    rating.append(title35)
rating[0:4]
rev15=driver5.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev15:
    title36=i.text
    rating.append(title36)
rating[0:4]
rev16=driver5.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev16:
    title37=i.text
    rating.append(title37)
rating[0:4]
rev17=driver5.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev17:
    title38=i.text
    rating.append(title38)
rating[0:4]
rev18=driver5.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev18:
    title39=i.text
    rating.append(title39)
rating[0:4]
rev19=driver5.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev19:
    title311=i.text
    rating.append(title311)
rating[0:4]
# Out:
# ['(264)\n264 product ratings - Kyocera Brigadier E6782 16GB Black (Verizon) Smartphone (GSM+CDMA) Cracked',
#  '(7)\n7 product ratings - Google Pixel 4 G020I - 64GB - Just Black (AT&T) GSM Smartphone with Android 11',
#  '(19)\n19 product ratings - Apple iPhone 8 (64gb) Metro/ T-Mobile/ Sprint (A1905) Product RED {iOS13}84%',
#  '(3)\n3 product ratings - Samsung Galaxy A51 5G SM-A516U 128GB Prism Cube Black AT&T Poor Condition']

# %%
print(len(mobile),len(rating))
# Out:
# 420 420

# %%
ebay=pd.DataFrame({})
ebay['ebay']=mobile[0:420]
ebay['review&rating']=rating[0:420]

# %%
ebay
# Out:
#                    ebay                                      review&rating
# 0      4 out of 5 stars  (264)\n264 product ratings - Kyocera Brigadier...
# 1      5 out of 5 stars  (7)\n7 product ratings - Google Pixel 4 G020I ...
# 2      5 out of 5 stars  (19)\n19 product ratings - Apple iPhone 8 (64g...
# 3    4.5 out of 5 stars  (3)\n3 product ratings - Samsung Galaxy A51 5G...
# 4      5 out of 5 stars  (30)\n30 product ratings - Samsung Galaxy S10 ...
# ..                  ...                                                ...
# 415  4.5 out of 5 stars  (98)\n98 product ratings - Apple iPhone 6s Plu...
# 416    4 out of 5 stars  (3)\n3 product ratings - Apple iPhone 8 64GB A...
# 417    5 out of 5 stars  (64)\n64 product ratings - [BROKEN) LG K20 plu...
# 418  4.5 out of 5 stars  (98)\n98 product ratings - Used Scratched Huaw...
# 419    5 out of 5 stars  (2)\n2 product ratings - Apple iPhone 7 PLUS 1...
#
# [420 rows x 2 columns]

# %%
ebay.to_csv("ebay.csv")

# %%
#lets first connect to the web driver
driver6=webdriver.Chrome(r"C://chromedriver.exe")

# %%
driver6.get('https://www.ebay.com/')

url='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=21'
url1='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=22'
url2='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=23'
url3='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=24'
url4='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=25'
url5='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=26'
url6='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=27'
url7='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=28'
url8='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=29'
url9='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=30'
url10='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=31'
url11='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=32'
url12='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=33'
url13='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=34'
url14='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=35'
url15='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=36'
url16='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=37'
url17='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=38'
url18='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=39'
url19='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=40'

driver6.get(url+url1+url2+url3+url4+url5+url6+url7+url8+url9+url10+url11+url12+url13+url14+url15+url16+url17+url18+url19)

# %%
rating=[]
mobile=[]

# %%
brand=driver6.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand:
    title5=i.text
    mobile.append(title5)
mobile[0:4] 
brand1=driver6.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand1:
    title92=i.text
    mobile.append(title92)
mobile[0:4] 
brand2=driver6.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand2:
    title82=i.text
    mobile.append(title82)
mobile[0:4] 
brand3=driver6.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand3:
    title72=i.text
    mobile.append(title72)
mobile[0:4] 
brand4=driver6.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand4:
    title62=i.text
    mobile.append(title62)
mobile[0:4] 
brand5=driver6.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand5:
    title52=i.text
    mobile.append(title52)
mobile[0:4] 
brand6=driver6.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand6:
    title42=i.text
    mobile.append(title42)
mobile[0:4] 
brand7=driver6.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand7:
    title32=i.text
    mobile.append(title32)
mobile[0:4] 
brand8=driver6.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand8:
    title31=i.text
    mobile.append(title31)
mobile[0:4] 
brand9=driver6.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand9:
    title3=i.text
    mobile.append(title3)
mobile[0:4] 
brand10=driver6.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand10:
    title29=i.text
    mobile.append(title29)
mobile[0:4] 
brand11=driver6.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand11:
    title28=i.text
    mobile.append(title28)
mobile[0:4] 
brand12=driver6.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand12:
    title27=i.text
    mobile.append(title27)
mobile[0:4] 
brand13=driver6.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand13:
    title26=i.text
    mobile.append(title26)
mobile[0:4] 
brand14=driver6.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand14:
    title25=i.text
    mobile.append(title25)
mobile[0:4] 
brand15=driver6.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand15:
    title24=i.text
    mobile.append(title24)
mobile[0:4] 
brand16=driver6.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand16:
    title23=i.text
    mobile.append(title23)
mobile[0:4] 
brand17=driver6.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand17:
    title1=i.text
    mobile.append(title1)
mobile[0:4] 
brand18=driver6.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand18:
    title22=i.text
    mobile.append(title22)
mobile[0:4] 
brand19=driver6.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand19:
    title2=i.text
    mobile.append(title2)
mobile[0:4]
# Out:
# ['4.5 out of 5 stars',
#  '4.5 out of 5 stars',
#  '5 out of 5 stars',
#  '4.5 out of 5 stars']

# %%
rev=driver6.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev:
    title3=i.text
    rating.append(title3)
rating[0:4]
rev1=driver6.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev1:
    title1=i.text
    rating.append(title1)
rating[0:4]
rev2=driver6.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev2:
    title2=i.text
    rating.append(title2)
rating[0:4]
rev3=driver6.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev3:
    title0=i.text
    rating.append(title0)
rating[0:4]
rev4=driver6.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev4:
    title4=i.text
    rating.append(title4)
rating[0:4]
rev5=driver6.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev5:
    title5=i.text
    rating.append(title5)
rating[0:4]
rev6=driver6.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev6:
    title6=i.text
    rating.append(title6)
rating[0:4]
rev7=driver6.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev7:
    title7=i.text
    rating.append(title7)
rating[0:4]
rev8=driver6.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev8:
    title8=i.text
    rating.append(title8)
rating[0:4]
rev9=driver6.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev9:
    title9=i.text
    rating.append(title9)
rating[0:4]
rev10=driver6.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev10:
    title31=i.text
    rating.append(title31)
rating[0:4]
rev11=driver6.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev11:
    title32=i.text
    rating.append(title32)
rating[0:4]
rev12=driver6.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev12:
    title33=i.text
    rating.append(title33)
rating[0:4]
rev13=driver6.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev13:
    title34=i.text
    rating.append(title34)
rating[0:4]
rev14=driver6.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev14:
    title35=i.text
    rating.append(title35)
rating[0:4]
rev15=driver6.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev15:
    title36=i.text
    rating.append(title36)
rating[0:4]
rev16=driver6.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev16:
    title37=i.text
    rating.append(title37)
rating[0:4]
rev17=driver6.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev17:
    title38=i.text
    rating.append(title38)
rating[0:4]
rev18=driver6.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev18:
    title39=i.text
    rating.append(title39)
rating[0:4]
rev19=driver6.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev19:
    title311=i.text
    rating.append(title311)
rating[0:4]
# Out:
# ['(43)\n43 product ratings - Google - Pixel 3 with 64GB Memory Cell Phone (Unlocked) - Not Pink - New SEALED',
#  '(15)\n15 product ratings - Apple iPhone 7 Unlocked 32GB Black - AT&T T-Mobile Verizon GSM Unlocked',
#  '(4)\n4 product ratings - Google - Pixel 3 XL with 128GB Memory Cell Phone (Unlocked) - Not Pink',
#  '(58)\n58 product ratings - Google Pixel 3 Pixel 3 XL 64GB CDMA + GSM Unlocked 4G LTE Android Smartphone']

# %%
print(len(mobile),len(rating))
# Out:
# 740 740

# %%
ebay1=pd.DataFrame({})
ebay1['ebay1']=mobile[0:740]
ebay1['review&rating']=rating[0:740]

# %%
ebay1
# Out:
#                   ebay1                                      review&rating
# 0    4.5 out of 5 stars  (43)\n43 product ratings - Google - Pixel 3 wi...
# 1    4.5 out of 5 stars  (15)\n15 product ratings - Apple iPhone 7 Unlo...
# 2      5 out of 5 stars  (4)\n4 product ratings - Google - Pixel 3 XL w...
# 3    4.5 out of 5 stars  (58)\n58 product ratings - Google Pixel 3 Pixe...
# 4    4.5 out of 5 stars  (17)\n17 product ratings - Apple iPhone 8 64GB...
# ..                  ...                                                ...
# 735    5 out of 5 stars  (13)\n13 product ratings - Google Pixel 1 Pixe...
# 736    5 out of 5 stars  (94)\n94 product ratings - TESTED BLACK CDMA +...
# 737  4.5 out of 5 stars  (40)\n40 product ratings - [SEALED] BlackBerry...
# 738  4.5 out of 5 stars  (59)\n59 product ratings - Apple iPhone 7 Plus...
# 739  4.5 out of 5 stars  (98)\n98 product ratings - Apple iPhone 7 Plus...
#
# [740 rows x 2 columns]

# %%
ebay1.to_csv("ebay1.csv")

# %%
#lets first connect to the web driver
driver7=webdriver.Chrome(r"C://chromedriver.exe")

# %%
driver7.get('https://www.ebay.com/')

url='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=40'
url1='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=41'
url2='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=42'
url3='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=43'
url4='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=44'
url5='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=45'
url6='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=46'
url7='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=47'
url8='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=48'
url9='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=49'
url10='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=50'
url11='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=51'
url12='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=52'
url13='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=53'
url14='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=54'
url15='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=55'
url16='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=56'
url17='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=57'
url18='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=58'
url19='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=59'

driver7.get(url+url1+url2+url3+url4+url5+url6+url7+url8+url9+url10+url11+url12+url13+url14+url15+url16+url17+url18+url19)

# %%
rating=[]
review=[]

# %%
brand=driver7.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand:
    title5=i.text
    mobile.append(title5)
mobile[0:4] 
brand1=driver7.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand1:
    title92=i.text
    mobile.append(title92)
mobile[0:4] 
brand2=driver7.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand2:
    title82=i.text
    mobile.append(title82)
mobile[0:4] 
brand3=driver7.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand3:
    title72=i.text
    mobile.append(title72)
mobile[0:4] 
brand4=driver7.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand4:
    title62=i.text
    mobile.append(title62)
mobile[0:4] 
brand5=driver7.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand5:
    title52=i.text
    mobile.append(title52)
mobile[0:4] 
brand6=driver7.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand6:
    title42=i.text
    mobile.append(title42)
mobile[0:4] 
brand7=driver7.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand7:
    title32=i.text
    mobile.append(title32)
mobile[0:4] 
brand8=driver7.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand8:
    title31=i.text
    mobile.append(title31)
mobile[0:4] 
brand9=driver7.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand9:
    title3=i.text
    mobile.append(title3)
mobile[0:4] 
brand10=driver7.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand10:
    title29=i.text
    mobile.append(title29)
mobile[0:4] 
brand11=driver7.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand11:
    title28=i.text
    mobile.append(title28)
mobile[0:4] 
brand12=driver7.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand12:
    title27=i.text
    mobile.append(title27)
mobile[0:4] 
brand13=driver7.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand13:
    title26=i.text
    mobile.append(title26)
mobile[0:4] 
brand14=driver7.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand14:
    title25=i.text
    mobile.append(title25)
mobile[0:4] 
brand15=driver7.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand15:
    title24=i.text
    mobile.append(title24)
mobile[0:4] 
brand16=driver7.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand16:
    title23=i.text
    mobile.append(title23)
mobile[0:4] 
brand17=driver7.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand17:
    title1=i.text
    mobile.append(title1)
mobile[0:4] 
brand18=driver7.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand18:
    title22=i.text
    mobile.append(title22)
mobile[0:4] 
brand19=driver7.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand19:
    title2=i.text
    mobile.append(title2)
mobile[0:4]
# Out:
# ['4.5 out of 5 stars',
#  '4.5 out of 5 stars',
#  '5 out of 5 stars',
#  '4.5 out of 5 stars']

# %%
rev=driver7.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev:
    title3=i.text
    rating.append(title3)
rating[0:4]
rev1=driver7.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev1:
    title1=i.text
    rating.append(title1)
rating[0:4]
rev2=driver7.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev2:
    title2=i.text
    rating.append(title2)
rating[0:4]
rev3=driver7.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev3:
    title0=i.text
    rating.append(title0)
rating[0:4]
rev4=driver7.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev4:
    title4=i.text
    rating.append(title4)
rating[0:4]
rev5=driver7.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev5:
    title5=i.text
    rating.append(title5)
rating[0:4]
rev6=driver7.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev6:
    title6=i.text
    rating.append(title6)
rating[0:4]
rev7=driver7.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev7:
    title7=i.text
    rating.append(title7)
rating[0:4]
rev8=driver7.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev8:
    title8=i.text
    rating.append(title8)
rating[0:4]
rev9=driver7.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev9:
    title9=i.text
    rating.append(title9)
rating[0:4]
rev10=driver7.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev10:
    title31=i.text
    rating.append(title31)
rating[0:4]
rev11=driver7.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev11:
    title32=i.text
    rating.append(title32)
rating[0:4]
rev12=driver7.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev12:
    title33=i.text
    rating.append(title33)
rating[0:4]
rev13=driver7.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev13:
    title34=i.text
    rating.append(title34)
rating[0:4]
rev14=driver7.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev14:
    title35=i.text
    rating.append(title35)
rating[0:4]
rev15=driver7.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev15:
    title36=i.text
    rating.append(title36)
rating[0:4]
rev16=driver7.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev16:
    title37=i.text
    rating.append(title37)
rating[0:4]
rev17=driver7.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev17:
    title38=i.text
    rating.append(title38)
rating[0:4]
rev18=driver7.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev18:
    title39=i.text
    rating.append(title39)
rating[0:4]
rev19=driver7.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev19:
    title311=i.text
    rating.append(title311)
rating[0:4]
# Out:
# ['(43)\n43 product ratings - Google - Pixel 3 with 64GB Memory Cell Phone (Unlocked) - Not Pink - New SEALED',
#  '(15)\n15 product ratings - Apple iPhone 7 Unlocked 32GB Black - AT&T T-Mobile Verizon GSM Unlocked',
#  '(4)\n4 product ratings - Google - Pixel 3 XL with 128GB Memory Cell Phone (Unlocked) - Not Pink',
#  '(58)\n58 product ratings - Google Pixel 3 Pixel 3 XL 64GB CDMA + GSM Unlocked 4G LTE Android Smartphone']

# %%
print(len(mobile),len(rating))
# Out:
# 1500 760

# %%
ebay2=pd.DataFrame({})
ebay2['ebay2']=mobile[0:760]
ebay2['review&rating']=rating[0:760]

# %%
ebay2
# Out:
#                   ebay2                                      review&rating
# 0    4.5 out of 5 stars  (43)\n43 product ratings - Google - Pixel 3 wi...
# 1    4.5 out of 5 stars  (15)\n15 product ratings - Apple iPhone 7 Unlo...
# 2      5 out of 5 stars  (4)\n4 product ratings - Google - Pixel 3 XL w...
# 3    4.5 out of 5 stars  (58)\n58 product ratings - Google Pixel 3 Pixe...
# 4    4.5 out of 5 stars  (1)\n1 product ratings - Apple iPhone 7 32GB F...
# ..                  ...                                                ...
# 755    5 out of 5 stars  (59)\n59 product ratings - Apple iPhone 7 Plus...
# 756  4.5 out of 5 stars  (98)\n98 product ratings - Apple iPhone 7 Plus...
# 757  4.5 out of 5 stars  (58)\n58 product ratings - Apple iPhone 7 Plus...
# 758    5 out of 5 stars  (1)\n1 product ratings - Apple iPhone 7 32GB U...
# 759  4.5 out of 5 stars  (257)\n257 product ratings - **NEW** SAMSUNG G...
#
# [760 rows x 2 columns]

# %%
ebay2.to_csv("ebay2.csv")

# %%
#lets first connect to the web driver
driver8=webdriver.Chrome(r"C://chromedriver.exe")

# %%
driver8.get('https://www.ebay.com/')

url='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=60'
url1='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=61'
url2='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=62'
url3='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=63'
url4='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=64'
url5='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=65'
url6='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=66'
url7='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=67'
url8='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=68'
url9='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=69'
url10='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=70'
url11='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=71'
url12='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=72'
url13='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=73'
url14='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=74'
url15='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=75'
url16='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=76'
url17='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=77'
url18='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=78'
url19='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=79'

driver8.get(url+url1+url2+url3+url4+url5+url6+url7+url8+url9+url10+url11+url12+url13+url14+url15+url16+url17+url18+url19)

# %%
rating=[]
review=[]

# %%
brand=driver8.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand:
    title5=i.text
    mobile.append(title5)
mobile[0:4] 
brand1=driver8.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand1:
    title92=i.text
    mobile.append(title92)
mobile[0:4] 
brand2=driver8.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand2:
    title82=i.text
    mobile.append(title82)
mobile[0:4] 
brand3=driver8.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand3:
    title72=i.text
    mobile.append(title72)
mobile[0:4] 
brand4=driver8.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand4:
    title62=i.text
    mobile.append(title62)
mobile[0:4] 
brand5=driver8.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand5:
    title52=i.text
    mobile.append(title52)
mobile[0:4] 
brand6=driver8.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand6:
    title42=i.text
    mobile.append(title42)
mobile[0:4] 
brand7=driver8.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand7:
    title32=i.text
    mobile.append(title32)
mobile[0:4] 
brand8=driver8.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand8:
    title31=i.text
    mobile.append(title31)
mobile[0:4] 
brand9=driver8.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand9:
    title3=i.text
    mobile.append(title3)
mobile[0:4] 
brand10=driver8.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand10:
    title29=i.text
    mobile.append(title29)
mobile[0:4] 
brand11=driver8.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand11:
    title28=i.text
    mobile.append(title28)
mobile[0:4] 
brand12=driver8.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand12:
    title27=i.text
    mobile.append(title27)
mobile[0:4] 
brand13=driver8.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand13:
    title26=i.text
    mobile.append(title26)
mobile[0:4] 
brand14=driver8.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand14:
    title25=i.text
    mobile.append(title25)
mobile[0:4] 
brand15=driver8.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand15:
    title24=i.text
    mobile.append(title24)
mobile[0:4] 
brand16=driver8.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand16:
    title23=i.text
    mobile.append(title23)
mobile[0:4] 
brand17=driver8.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand17:
    title1=i.text
    mobile.append(title1)
mobile[0:4] 
brand18=driver8.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand18:
    title22=i.text
    mobile.append(title22)
mobile[0:4] 
brand19=driver8.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand19:
    title2=i.text
    mobile.append(title2)
mobile[0:4]
# Out:
# ['4.5 out of 5 stars',
#  '4.5 out of 5 stars',
#  '5 out of 5 stars',
#  '4.5 out of 5 stars']

# %%
rev=driver8.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev:
    title3=i.text
    rating.append(title3)
rating[0:4]
rev1=driver8.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev1:
    title1=i.text
    rating.append(title1)
rating[0:4]
rev2=driver8.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev2:
    title2=i.text
    rating.append(title2)
rating[0:4]
rev3=driver8.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev3:
    title0=i.text
    rating.append(title0)
rating[0:4]
rev4=driver8.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev4:
    title4=i.text
    rating.append(title4)
rating[0:4]
rev5=driver8.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev5:
    title5=i.text
    rating.append(title5)
rating[0:4]
rev6=driver8.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev6:
    title6=i.text
    rating.append(title6)
rating[0:4]
rev7=driver8.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev7:
    title7=i.text
    rating.append(title7)
rating[0:4]
rev8=driver8.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev8:
    title8=i.text
    rating.append(title8)
rating[0:4]
rev9=driver8.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev9:
    title9=i.text
    rating.append(title9)
rating[0:4]
rev10=driver8.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev10:
    title31=i.text
    rating.append(title31)
rating[0:4]
rev11=driver8.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev11:
    title32=i.text
    rating.append(title32)
rating[0:4]
rev12=driver8.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev12:
    title33=i.text
    rating.append(title33)
rating[0:4]
rev13=driver8.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev13:
    title34=i.text
    rating.append(title34)
rating[0:4]
rev14=driver8.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev14:
    title35=i.text
    rating.append(title35)
rating[0:4]
rev15=driver8.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev15:
    title36=i.text
    rating.append(title36)
rating[0:4]
rev16=driver8.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev16:
    title37=i.text
    rating.append(title37)
rating[0:4]
rev17=driver8.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev17:
    title38=i.text
    rating.append(title38)
rating[0:4]
rev18=driver8.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev18:
    title39=i.text
    rating.append(title39)
rating[0:4]
rev19=driver8.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev19:
    title311=i.text
    rating.append(title311)
rating[0:4]
# Out:
# ['(43)\n43 product ratings - Google - Pixel 3 with 64GB Memory Cell Phone (Unlocked) - Not Pink - New SEALED',
#  '(15)\n15 product ratings - Apple iPhone 7 Unlocked 32GB Black - AT&T T-Mobile Verizon GSM Unlocked',
#  '(4)\n4 product ratings - Google - Pixel 3 XL with 128GB Memory Cell Phone (Unlocked) - Not Pink',
#  '(58)\n58 product ratings - Google Pixel 3 Pixel 3 XL 64GB CDMA + GSM Unlocked 4G LTE Android Smartphone']

# %%
print(len(mobile),len(rating))
# Out:
# 2240 740

# %%
ebay3=pd.DataFrame({})
ebay3['ebay3']=mobile[0:740]
ebay3['review&rating']=rating[0:740]

# %%
ebay3
# Out:
#                   ebay3                                      review&rating
# 0    4.5 out of 5 stars  (43)\n43 product ratings - Google - Pixel 3 wi...
# 1    4.5 out of 5 stars  (15)\n15 product ratings - Apple iPhone 7 Unlo...
# 2      5 out of 5 stars  (4)\n4 product ratings - Google - Pixel 3 XL w...
# 3    4.5 out of 5 stars  (58)\n58 product ratings - Google Pixel 3 Pixe...
# 4    4.5 out of 5 stars  (17)\n17 product ratings - Apple iPhone 8 64GB...
# ..                  ...                                                ...
# 735    5 out of 5 stars  (94)\n94 product ratings - TESTED BLACK CDMA +...
# 736    5 out of 5 stars  (40)\n40 product ratings - [SEALED] BlackBerry...
# 737  4.5 out of 5 stars  (59)\n59 product ratings - Apple iPhone 7 Plus...
# 738  4.5 out of 5 stars  (98)\n98 product ratings - Apple iPhone 7 Plus...
# 739  4.5 out of 5 stars  (58)\n58 product ratings - Apple iPhone 7 Plus...
#
# [740 rows x 2 columns]

# %%
ebay3.to_csv("ebay3.csv")

# %%
#lets first connect to the web driver
driver9=webdriver.Chrome(r"C://chromedriver.exe")

# %%
driver9.get('https://www.ebay.com/')

url='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=80'
url1='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=81'
url2='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=82'
url3='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=83'
url4='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=84'
url5='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=85'
url6='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=86'
url7='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=87'
url8='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=88'
url9='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=89'
url10='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=90'
url11='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=91'
url12='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=92'
url13='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=93'
url14='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=94'
url15='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=95'
url16='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=96'
url17='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=97'
url18='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=98'
url19='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=99'

driver9.get(url+url1+url2+url3+url4+url5+url6+url7+url8+url9+url10+url11+url12+url13+url14+url15+url16+url17+url18+url19)

# %%
rating=[]
review=[]

# %%
brand=driver9.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand:
    title5=i.text
    mobile.append(title5)
mobile[0:4] 
brand1=driver9.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand1:
    title92=i.text
    mobile.append(title92)
mobile[0:4] 
brand2=driver9.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand2:
    title82=i.text
    mobile.append(title82)
mobile[0:4] 
brand3=driver9.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand3:
    title72=i.text
    mobile.append(title72)
mobile[0:4] 
brand4=driver9.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand4:
    title62=i.text
    mobile.append(title62)
mobile[0:4] 
brand5=driver9.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand5:
    title52=i.text
    mobile.append(title52)
mobile[0:4] 
brand6=driver9.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand6:
    title42=i.text
    mobile.append(title42)
mobile[0:4] 
brand7=driver9.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand7:
    title32=i.text
    mobile.append(title32)
mobile[0:4] 
brand8=driver9.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand8:
    title31=i.text
    mobile.append(title31)
mobile[0:4] 
brand9=driver9.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand9:
    title3=i.text
    mobile.append(title3)
mobile[0:4] 
brand10=driver9.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand10:
    title29=i.text
    mobile.append(title29)
mobile[0:4] 
brand11=driver9.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand11:
    title28=i.text
    mobile.append(title28)
mobile[0:4] 
brand12=driver9.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand12:
    title27=i.text
    mobile.append(title27)
mobile[0:4] 
brand13=driver9.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand13:
    title26=i.text
    mobile.append(title26)
mobile[0:4] 
brand14=driver9.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand14:
    title25=i.text
    mobile.append(title25)
mobile[0:4] 
brand15=driver9.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand15:
    title24=i.text
    mobile.append(title24)
mobile[0:4] 
brand16=driver9.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand16:
    title23=i.text
    mobile.append(title23)
mobile[0:4] 
brand17=driver9.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand17:
    title1=i.text
    mobile.append(title1)
mobile[0:4] 
brand18=driver9.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand18:
    title22=i.text
    mobile.append(title22)
mobile[0:4] 
brand19=driver9.find_elements_by_xpath('//div[@class="b-starrating"]')
for i in brand19:
    title2=i.text
    mobile.append(title2)
mobile[0:4]
# Out:
# ['4.5 out of 5 stars',
#  '4.5 out of 5 stars',
#  '5 out of 5 stars',
#  '4.5 out of 5 stars']

# %%
rev=driver9.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev:
    title3=i.text
    rating.append(title3)
rating[0:4]
rev1=driver9.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev1:
    title1=i.text
    rating.append(title1)
rating[0:4]
rev2=driver9.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev2:
    title2=i.text
    rating.append(title2)
rating[0:4]
rev3=driver9.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev3:
    title0=i.text
    rating.append(title0)
rating[0:4]
rev4=driver9.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev4:
    title4=i.text
    rating.append(title4)
rating[0:4]
rev5=driver9.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev5:
    title5=i.text
    rating.append(title5)
rating[0:4]
rev6=driver9.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev6:
    title6=i.text
    rating.append(title6)
rating[0:4]
rev7=driver9.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev7:
    title7=i.text
    rating.append(title7)
rating[0:4]
rev8=driver9.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev8:
    title8=i.text
    rating.append(title8)
rating[0:4]
rev9=driver9.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev9:
    title9=i.text
    rating.append(title9)
rating[0:4]
rev10=driver9.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev10:
    title31=i.text
    rating.append(title31)
rating[0:4]
rev11=driver9.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev11:
    title32=i.text
    rating.append(title32)
rating[0:4]
rev12=driver9.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev12:
    title33=i.text
    rating.append(title33)
rating[0:4]
rev13=driver9.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev13:
    title34=i.text
    rating.append(title34)
rating[0:4]
rev14=driver9.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev14:
    title35=i.text
    rating.append(title35)
rating[0:4]
rev15=driver9.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev15:
    title36=i.text
    rating.append(title36)
rating[0:4]
rev16=driver9.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev16:
    title37=i.text
    rating.append(title37)
rating[0:4]
rev17=driver9.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev17:
    title38=i.text
    rating.append(title38)
rating[0:4]
rev18=driver9.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev18:
    title39=i.text
    rating.append(title39)
rating[0:4]
rev19=driver9.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev19:
    title311=i.text
    rating.append(title311)
rating[0:4]
# Out:
# ['(43)\n43 product ratings - Google - Pixel 3 with 64GB Memory Cell Phone (Unlocked) - Not Pink - New SEALED',
#  '(15)\n15 product ratings - Apple iPhone 7 Unlocked 32GB Black - AT&T T-Mobile Verizon GSM Unlocked',
#  '(4)\n4 product ratings - Google - Pixel 3 XL with 128GB Memory Cell Phone (Unlocked) - Not Pink',
#  '(58)\n58 product ratings - Google Pixel 3 Pixel 3 XL 64GB CDMA + GSM Unlocked 4G LTE Android Smartphone']

# %%
print(len(mobile),len(rating))
# Out:
# 2980 740

# %%
ebay4=pd.DataFrame({})
ebay4['ebay4']=mobile[0:740]
ebay4['review&rating']=rating[0:740]

# %%
ebay4
# Out:
#                   ebay4                                      review&rating
# 0    4.5 out of 5 stars  (43)\n43 product ratings - Google - Pixel 3 wi...
# 1    4.5 out of 5 stars  (15)\n15 product ratings - Apple iPhone 7 Unlo...
# 2      5 out of 5 stars  (4)\n4 product ratings - Google - Pixel 3 XL w...
# 3    4.5 out of 5 stars  (58)\n58 product ratings - Google Pixel 3 Pixe...
# 4    4.5 out of 5 stars  (17)\n17 product ratings - Apple iPhone 8 64GB...
# ..                  ...                                                ...
# 735    5 out of 5 stars  (94)\n94 product ratings - TESTED BLACK CDMA +...
# 736    5 out of 5 stars  (40)\n40 product ratings - [SEALED] BlackBerry...
# 737  4.5 out of 5 stars  (59)\n59 product ratings - Apple iPhone 7 Plus...
# 738  4.5 out of 5 stars  (98)\n98 product ratings - Apple iPhone 7 Plus...
# 739  4.5 out of 5 stars  (58)\n58 product ratings - Apple iPhone 7 Plus...
#
# [740 rows x 2 columns]

# %%
ebay4.to_csv("ebay4.csv")

# %%
#lets first connect to the web driver
driver10=webdriver.Chrome(r"C://chromedriver.exe")

# %%
driver10.get('https://www.ebay.com/')

url='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=100'
url1='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=101'
url2='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=102'
url3='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=103'
url4='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=104'
url5='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=105'
url6='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=106'
url7='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=107'
url8='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=108'
url9='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=109'
url10='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=110'
url11='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=111'
url12='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=112'
url13='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=113'
url14='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=114'
url15='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=115'
url16='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=116'
url17='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=117'
url18='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=118'
url19='https://www.ebay.com/b/Cell-Phones-Smartphones/9355/bn_320094?rt=nc&_pgn=119'

driver10.get(url+url1+url2+url3+url4+url5+url6+url7+url8+url9+url10+url11+url12+url13+url14+url15+url16+url17+url18+url19)

# %%
rating=[]
review=[]

# %%
rev=driver10.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev:
    title3=i.text
    rating.append(title3)
rating[0:4]
rev1=driver10.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev1:
    title1=i.text
    rating.append(title1)
rating[0:4]
rev2=driver10.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev2:
    title2=i.text
    rating.append(title2)
rating[0:4]
rev3=driver10.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev3:
    title0=i.text
    rating.append(title0)
rating[0:4]
rev4=driver10.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev4:
    title4=i.text
    rating.append(title4)
rating[0:4]
rev5=driver10.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev5:
    title5=i.text
    rating.append(title5)
rating[0:4]
rev6=driver10.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev6:
    title6=i.text
    rating.append(title6)
rating[0:4]
rev7=driver10.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev7:
    title7=i.text
    rating.append(title7)
rating[0:4]
rev8=driver10.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev8:
    title8=i.text
    rating.append(title8)
rating[0:4]
rev9=driver10.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev9:
    title9=i.text
    rating.append(title9)
rating[0:4]
rev10=driver10.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev10:
    title31=i.text
    rating.append(title31)
rating[0:4]
rev11=driver10.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev11:
    title32=i.text
    rating.append(title32)
rating[0:4]
rev12=driver10.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev12:
    title33=i.text
    rating.append(title33)
rating[0:4]
rev13=driver10.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev13:
    title34=i.text
    rating.append(title34)
rating[0:4]
rev14=driver10.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev14:
    title35=i.text
    rating.append(title35)
rating[0:4]
rev15=driver10.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev15:
    title36=i.text
    rating.append(title36)
rating[0:4]
rev16=driver10.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev16:
    title37=i.text
    rating.append(title37)
rating[0:4]
rev17=driver10.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev17:
    title38=i.text
    rating.append(title38)
rating[0:4]
rev18=driver10.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev18:
    title39=i.text
    rating.append(title39)
rating[0:4]
rev19=driver10.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev19:
    title311=i.text
    rating.append(title311)
rating[0:4]
# Out:
# ['(43)\n43 product ratings - Google - Pixel 3 with 64GB Memory Cell Phone (Unlocked) - Not Pink - New SEALED',
#  '(15)\n15 product ratings - Apple iPhone 7 Unlocked 32GB Black - AT&T T-Mobile Verizon GSM Unlocked',
#  '(4)\n4 product ratings - Google - Pixel 3 XL with 128GB Memory Cell Phone (Unlocked) - Not Pink',
#  '(58)\n58 product ratings - Google Pixel 3 Pixel 3 XL 64GB CDMA + GSM Unlocked 4G LTE Android Smartphone']

# %%
print(len(mobile),len(rating))
# Out:
# 3208 1254

# %%
url14='https://www.ebay.com/sch/i.html?_from=R40&_nkw=monitors&_sacat=0&LH_TitleDesc=0&_pgn=14'
url15='https://www.ebay.com/sch/i.html?_from=R40&_nkw=monitors&_sacat=0&LH_TitleDesc=0&_pgn=15'
url16='https://www.ebay.com/sch/i.html?_from=R40&_nkw=monitors&_sacat=0&LH_TitleDesc=0&_pgn=16'
url17='https://www.ebay.com/sch/i.html?_from=R40&_nkw=monitors&_sacat=0&LH_TitleDesc=0&_pgn=17'
url18='https://www.ebay.com/sch/i.html?_from=R40&_nkw=monitors&_sacat=0&LH_TitleDesc=0&_pgn=18'
url19='https://www.ebay.com/sch/i.html?_from=R40&_nkw=monitors&_sacat=0&LH_TitleDesc=0&_pgn=19'

driver11.get(url+url1+url2+url3+url4+url5+url6+url7+url8+url9+url10+url11+url12+url13+url14+url15+url16+url17+url18+url19)

# %%
rating=[]
mobile=[]

# %%
brand=driver11.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand:
    title5=i.text
    mobile.append(title5)
mobile[0:4] 
brand1=driver11.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand1:
    title92=i.text
    mobile.append(title92)
mobile[0:4] 
brand2=driver11.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand2:
    title82=i.text
    mobile.append(title82)
mobile[0:4] 
brand3=driver11.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand3:
    title72=i.text
    mobile.append(title72)
mobile[0:4] 
brand4=driver11.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand4:
    title62=i.text
    mobile.append(title62)
mobile[0:4] 
brand5=driver11.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand5:
    title52=i.text
    mobile.append(title52)
mobile[0:4] 
brand6=driver11.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand6:
    title42=i.text
    mobile.append(title42)
mobile[0:4] 
brand7=driver11.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand7:
    title32=i.text
    mobile.append(title32)
mobile[0:4] 
brand8=driver11.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand8:
    title31=i.text
    mobile.append(title31)
mobile[0:4] 
brand9=driver11.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand9:
    title3=i.text
    mobile.append(title3)
mobile[0:4] 
brand10=driver11.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand10:
    title29=i.text
    mobile.append(title29)
mobile[0:4] 
brand11=driver11.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand11:
    title28=i.text
    mobile.append(title28)
mobile[0:4] 
brand12=driver11.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand12:
    title27=i.text
    mobile.append(title27)
mobile[0:4] 
brand13=driver11.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand13:
    title26=i.text
    mobile.append(title26)
mobile[0:4] 
brand14=driver11.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand14:
    title25=i.text
    mobile.append(title25)
mobile[0:4] 
brand15=driver11.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand15:
    title24=i.text
    mobile.append(title24)
mobile[0:4] 
brand16=driver11.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand16:
    title23=i.text
    mobile.append(title23)
mobile[0:4] 
brand17=driver11.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand17:
    title1=i.text
    mobile.append(title1)
mobile[0:4] 
brand18=driver11.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand18:
    title22=i.text
    mobile.append(title22)
mobile[0:4] 
brand19=driver11.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand19:
    title2=i.text
    mobile.append(title2)
mobile[0:4]
# Out:
# ['4.5 out of 5 stars.',
#  '5.0 out of 5 stars.',
#  '5.0 out of 5 stars.',
#  '4.5 out of 5 stars.']

# %%
rev=driver11.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev:
    title3=i.text
    rating.append(title3)
rating[0:4]
rev1=driver11.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev1:
    title1=i.text
    rating.append(title1)
rating[0:4]
rev2=driver11.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev2:
    title2=i.text
    rating.append(title2)
rating[0:4]
rev3=driver11.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev3:
    title0=i.text
    rating.append(title0)
rating[0:4]
rev4=driver11.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev4:
    title4=i.text
    rating.append(title4)
rating[0:4]
rev5=driver11.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev5:
    title5=i.text
    rating.append(title5)
rating[0:4]
rev6=driver11.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev6:
    title6=i.text
    rating.append(title6)
rating[0:4]
rev7=driver11.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev7:
    title7=i.text
    rating.append(title7)
rating[0:4]
rev8=driver11.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev8:
    title8=i.text
    rating.append(title8)
rating[0:4]
rev9=driver11.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev9:
    title9=i.text
    rating.append(title9)
rating[0:4]
rev10=driver11.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev10:
    title31=i.text
    rating.append(title31)
rating[0:4]
rev11=driver11.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev11:
    title32=i.text
    rating.append(title32)
rating[0:4]
rev12=driver11.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev12:
    title33=i.text
    rating.append(title33)
rating[0:4]
rev13=driver11.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev13:
    title34=i.text
    rating.append(title34)
rating[0:4]
rev14=driver11.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev14:
    title35=i.text
    rating.append(title35)
rating[0:4]
rev15=driver11.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev15:
    title36=i.text
    rating.append(title36)
rating[0:4]
rev16=driver11.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev16:
    title37=i.text
    rating.append(title37)
rating[0:4]
rev17=driver11.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev17:
    title38=i.text
    rating.append(title38)
rating[0:4]
rev18=driver11.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev18:
    title39=i.text
    rating.append(title39)
rating[0:4]
rev19=driver11.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev19:
    title311=i.text
    rating.append(title311)
rating[0:4]
# Out:
# ['4 product ratings\n- 19" 5-Wire Touchscreen LCD VGA 19 inch Touch Screen Monitor POS USA Seller',
#  '5 product ratings\n- Dell 1907FPVT LCD Monitor',
#  '1 product rating\n- HP 3UA74AA 27 YH 27 inch LED Backlit IPS Monitor with 1920 x 1080 Full HD NEW',
#  '5 product ratings\n- LG 24" IPS LED FHD Monitor 1920 x 1080 FreeSync Black 24ML44B-B']

# %%
print(len(mobile),len(rating))
# Out:
# 546 520

# %%
comp=pd.DataFrame({})
comp['comp']=mobile[0:520]
comp['review&rating']=rating[0:520]

# %%
comp
# Out:
#                     comp                                      review&rating
# 0    4.5 out of 5 stars.  4 product ratings\n- 19" 5-Wire Touchscreen LC...
url17='https://www.ebay.com/sch/i.html?_from=R40&_nkw=monitors&_sacat=0&LH_TitleDesc=0&_pgn=37'
url18='https://www.ebay.com/sch/i.html?_from=R40&_nkw=monitors&_sacat=0&LH_TitleDesc=0&_pgn=38'
url19='https://www.ebay.com/sch/i.html?_from=R40&_nkw=monitors&_sacat=0&LH_TitleDesc=0&_pgn=39'

driver12.get(url+url1+url2+url3+url4+url5+url6+url7+url8+url9+url10+url11+url12+url13+url14+url15+url16+url17+url18+url19)

# %%
brand=driver12.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand:
    title5=i.text
    mobile.append(title5)
mobile[0:4] 
brand1=driver12.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand1:
    title92=i.text
    mobile.append(title92)
mobile[0:4] 
brand2=driver12.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand2:
    title82=i.text
    mobile.append(title82)
mobile[0:4] 
brand3=driver12.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand3:
    title72=i.text
    mobile.append(title72)
mobile[0:4] 
brand4=driver12.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand4:
    title62=i.text
    mobile.append(title62)
mobile[0:4] 
brand5=driver12.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand5:
    title52=i.text
    mobile.append(title52)
mobile[0:4] 
brand6=driver12.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand6:
    title42=i.text
    mobile.append(title42)
mobile[0:4] 
brand7=driver12.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand7:
    title32=i.text
    mobile.append(title32)
mobile[0:4] 
brand8=driver12.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand8:
    title31=i.text
    mobile.append(title31)
mobile[0:4] 
brand9=driver12.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand9:
    title3=i.text
    mobile.append(title3)
mobile[0:4] 
brand10=driver12.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand10:
    title29=i.text
    mobile.append(title29)
mobile[0:4] 
brand11=driver12.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand11:
    title28=i.text
    mobile.append(title28)
mobile[0:4] 
brand12=driver12.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand12:
    title27=i.text
    mobile.append(title27)
mobile[0:4] 
brand13=driver12.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand13:
    title26=i.text
    mobile.append(title26)
mobile[0:4] 
brand14=driver12.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand14:
    title25=i.text
    mobile.append(title25)
mobile[0:4] 
brand15=driver12.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand15:
    title24=i.text
    mobile.append(title24)
mobile[0:4] 
brand16=driver12.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand16:
    title23=i.text
    mobile.append(title23)
mobile[0:4] 
brand17=driver12.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand17:
    title1=i.text
    mobile.append(title1)
mobile[0:4] 
brand18=driver12.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand18:
    title22=i.text
    mobile.append(title22)
mobile[0:4] 
brand19=driver12.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand19:
    title2=i.text
    mobile.append(title2)
mobile[0:4]
# Out:
# ['4.5 out of 5 stars.',
#  '5.0 out of 5 stars.',
#  '5.0 out of 5 stars.',
#  '4.5 out of 5 stars.']

# %%
rev=driver12.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev:
    title3=i.text
    rating.append(title3)
rating[0:4]
rev1=driver12.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev1:
    title1=i.text
    rating.append(title1)
rating[0:4]
rev2=driver12.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev2:
    title2=i.text
    rating.append(title2)
rating[0:4]
rev3=driver12.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev3:
    title0=i.text
    rating.append(title0)
rating[0:4]
rev4=driver12.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev4:
    title4=i.text
    rating.append(title4)
rating[0:4]
rev5=driver12.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev5:
    title5=i.text
    rating.append(title5)
rating[0:4]
rev6=driver12.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev6:
    title6=i.text
    rating.append(title6)
rating[0:4]
rev7=driver12.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev7:
    title7=i.text
    rating.append(title7)
rating[0:4]
rev8=driver12.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev8:
    title8=i.text
    rating.append(title8)
rating[0:4]
rev9=driver12.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev9:
    title9=i.text
    rating.append(title9)
rating[0:4]
rev10=driver12.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev10:
    title31=i.text
    rating.append(title31)
rating[0:4]
rev11=driver12.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev11:
    title32=i.text
    rating.append(title32)
rating[0:4]
rev12=driver12.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev12:
    title33=i.text
    rating.append(title33)
rating[0:4]
rev13=driver12.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev13:
    title34=i.text
    rating.append(title34)
rating[0:4]
rev14=driver12.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev14:
    title35=i.text
    rating.append(title35)
rating[0:4]
rev15=driver12.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev15:
    title36=i.text
    rating.append(title36)
rating[0:4]
rev16=driver12.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev16:
    title37=i.text
    rating.append(title37)
rating[0:4]
rev17=driver12.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev17:
    title38=i.text
    rating.append(title38)
rating[0:4]
rev18=driver12.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev18:
    title39=i.text
    rating.append(title39)
rating[0:4]
rev19=driver12.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev19:
    title311=i.text
    rating.append(title311)
rating[0:4]
# Out:
# ['4 product ratings\n- 19" 5-Wire Touchscreen LCD VGA 19 inch Touch Screen Monitor POS USA Seller',
#  '5 product ratings\n- Dell 1907FPVT LCD Monitor',
#  '1 product rating\n- HP 3UA74AA 27 YH 27 inch LED Backlit IPS Monitor with 1920 x 1080 Full HD NEW',
#  '5 product ratings\n- LG 24" IPS LED FHD Monitor 1920 x 1080 FreeSync Black 24ML44B-B']

# %%
print(len(mobile),len(rating))
# Out:
# 1066 1040

# %%
comp1=pd.DataFrame({})
comp1['comp1']=mobile[0:1040]
comp1['review&rating']=rating[0:1040]

# %%
comp1
# Out:
#                     comp1                                      review&rating
# 0     4.5 out of 5 stars.  4 product ratings\n- 19" 5-Wire Touchscreen LC...
# 1     5.0 out of 5 stars.     5 product ratings\n- Dell 1907FPVT LCD Monitor
# 2     5.0 out of 5 stars.  1 product rating\n- HP 3UA74AA 27 YH 27 inch L...
# 3     4.5 out of 5 stars.  5 product ratings\n- LG 24" IPS LED FHD Monito...
# 4     4.0 out of 5 stars.  5 product ratings\n- LG 24" UltraGear FHD 144H...
url19='https://www.ebay.com/sch/i.html?_from=R40&_nkw=headphones&_sacat=0&LH_TitleDesc=0&_pgn=20'

driver13.get(url+url1+url2+url3+url4+url5+url6+url7+url8+url9+url10+url11+url12+url13+url14+url15+url16+url17+url18+url19)

# %%
brand=driver13.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand:
    title5=i.text
    mobile.append(title5)
mobile[0:4] 
brand1=driver13.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand1:
    title92=i.text
    mobile.append(title92)
mobile[0:4] 
brand2=driver13.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand2:
    title82=i.text
    mobile.append(title82)
mobile[0:4] 
brand3=driver13.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand3:
    title72=i.text
    mobile.append(title72)
mobile[0:4] 
brand4=driver13.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand4:
    title62=i.text
    mobile.append(title62)
mobile[0:4] 
brand5=driver13.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand5:
    title52=i.text
    mobile.append(title52)
mobile[0:4] 
brand6=driver13.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand6:
    title42=i.text
    mobile.append(title42)
mobile[0:4] 
brand7=driver13.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand7:
    title32=i.text
    mobile.append(title32)
mobile[0:4] 
brand8=driver13.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand8:
    title31=i.text
    mobile.append(title31)
mobile[0:4] 
brand9=driver13.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand9:
    title3=i.text
    mobile.append(title3)
mobile[0:4] 
brand10=driver13.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand10:
    title29=i.text
    mobile.append(title29)
mobile[0:4] 
brand11=driver13.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand11:
    title28=i.text
    mobile.append(title28)
mobile[0:4] 
brand12=driver13.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand12:
    title27=i.text
    mobile.append(title27)
mobile[0:4] 
brand13=driver13.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand13:
    title26=i.text
    mobile.append(title26)
mobile[0:4] 
brand14=driver13.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand14:
    title25=i.text
    mobile.append(title25)
mobile[0:4] 
brand15=driver13.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand15:
    title24=i.text
    mobile.append(title24)
mobile[0:4] 
brand16=driver13.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand16:
    title23=i.text
    mobile.append(title23)
mobile[0:4] 
brand17=driver13.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand17:
    title1=i.text
    mobile.append(title1)
mobile[0:4] 
brand18=driver13.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand18:
    title22=i.text
    mobile.append(title22)
mobile[0:4] 
brand19=driver13.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand19:
    title2=i.text
    mobile.append(title2)
mobile[0:4]
# Out:
# ['4.5 out of 5 stars.',
#  '5.0 out of 5 stars.',
#  '5.0 out of 5 stars.',
#  '4.5 out of 5 stars.']

# %%
rev=driver13.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev:
    title3=i.text
    rating.append(title3)
rating[0:4]
rev1=driver13.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev1:
    title1=i.text
    rating.append(title1)
rating[0:4]
rev2=driver13.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev2:
    title2=i.text
    rating.append(title2)
rating[0:4]
rev3=driver13.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev3:
    title0=i.text
    rating.append(title0)
rating[0:4]
rev4=driver13.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev4:
    title4=i.text
    rating.append(title4)
rating[0:4]
rev5=driver13.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev5:
    title5=i.text
    rating.append(title5)
rating[0:4]
rev6=driver13.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev6:
    title6=i.text
    rating.append(title6)
rating[0:4]
rev7=driver13.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev7:
    title7=i.text
    rating.append(title7)
rating[0:4]
rev8=driver13.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev8:
    title8=i.text
    rating.append(title8)
rating[0:4]
rev9=driver13.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev9:
    title9=i.text
    rating.append(title9)
rating[0:4]
rev10=driver13.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev10:
    title31=i.text
    rating.append(title31)
rating[0:4]
rev11=driver13.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev11:
    title32=i.text
    rating.append(title32)
rating[0:4]
rev12=driver13.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev12:
    title33=i.text
    rating.append(title33)
rating[0:4]
rev13=driver13.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev13:
    title34=i.text
    rating.append(title34)
rating[0:4]
rev14=driver13.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev14:
    title35=i.text
    rating.append(title35)
rating[0:4]
rev15=driver13.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev15:
    title36=i.text
    rating.append(title36)
rating[0:4]
rev16=driver13.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev16:
    title37=i.text
    rating.append(title37)
rating[0:4]
rev17=driver13.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev17:
    title38=i.text
    rating.append(title38)
rating[0:4]
rev18=driver13.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev18:
    title39=i.text
    rating.append(title39)
rating[0:4]
rev19=driver13.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev19:
    title311=i.text
    rating.append(title311)
rating[0:4]
# Out:
# ['4 product ratings\n- 19" 5-Wire Touchscreen LCD VGA 19 inch Touch Screen Monitor POS USA Seller',
#  '5 product ratings\n- Dell 1907FPVT LCD Monitor',
#  '1 product rating\n- HP 3UA74AA 27 YH 27 inch LED Backlit IPS Monitor with 1920 x 1080 Full HD NEW',
#  '5 product ratings\n- LG 24" IPS LED FHD Monitor 1920 x 1080 FreeSync Black 24ML44B-B']

# %%
print(len(mobile),len(rating))
# Out:
# 1466 1440

# %%
hp=pd.DataFrame({})
hp['hp']=mobile[0:1440]
hp['review&rating']=rating[0:1440]

# %%
hp
# Out:
#                        hp                                      review&rating
# 0     4.5 out of 5 stars.  4 product ratings\n- 19" 5-Wire Touchscreen LC...
# 1     5.0 out of 5 stars.     5 product ratings\n- Dell 1907FPVT LCD Monitor
# 2     5.0 out of 5 stars.  1 product rating\n- HP 3UA74AA 27 YH 27 inch L...
# 3     4.5 out of 5 stars.  5 product ratings\n- LG 24" IPS LED FHD Monito...
# 4     4.0 out of 5 stars.  5 product ratings\n- LG 24" UltraGear FHD 144H...
# ...                   ...                                                ...
# 1435  4.5 out of 5 stars.  69 product ratings\n- Sony Headphone Over-Head...
# 1436  5.0 out of 5 stars.  24 product ratings\n- beyerdynamic DT 1990 Pro...
# 1437  5.0 out of 5 stars.  77 product ratings\n- Sony WH-H910N h.ear on 3...
    title5=i.text
    mobile.append(title5)
mobile[0:4] 
brand1=driver14.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand1:
    title92=i.text
    mobile.append(title92)
mobile[0:4] 
brand2=driver14.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand2:
    title82=i.text
    mobile.append(title82)
mobile[0:4] 
brand3=driver14.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand3:
    title72=i.text
    mobile.append(title72)
mobile[0:4] 
brand4=driver14.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand4:
    title62=i.text
    mobile.append(title62)
mobile[0:4] 
brand5=driver14.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand5:
    title52=i.text
    mobile.append(title52)
mobile[0:4] 
brand6=driver14.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand6:
    title42=i.text
    mobile.append(title42)
mobile[0:4] 
brand7=driver14.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand7:
    title32=i.text
    mobile.append(title32)
mobile[0:4] 
brand8=driver14.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand8:
    title31=i.text
    mobile.append(title31)
mobile[0:4] 
brand9=driver14.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand9:
    title3=i.text
    mobile.append(title3)
mobile[0:4] 
brand10=driver14.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand10:
    title29=i.text
    mobile.append(title29)
mobile[0:4] 
brand11=driver14.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand11:
    title28=i.text
    mobile.append(title28)
mobile[0:4] 
brand12=driver14.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand12:
    title27=i.text
    mobile.append(title27)
mobile[0:4] 
brand13=driver14.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand13:
    title26=i.text
    mobile.append(title26)
mobile[0:4] 
brand14=driver14.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand14:
    title25=i.text
    mobile.append(title25)
mobile[0:4] 
brand15=driver14.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand15:
    title24=i.text
    mobile.append(title24)
mobile[0:4] 
brand16=driver14.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand16:
    title23=i.text
    mobile.append(title23)
mobile[0:4] 
brand17=driver14.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand17:
    title1=i.text
    mobile.append(title1)
mobile[0:4] 
brand18=driver14.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand18:
    title22=i.text
    mobile.append(title22)
mobile[0:4] 
brand19=driver14.find_elements_by_xpath('//div[@class="x-star-rating"]')
for i in brand19:
    title2=i.text
    mobile.append(title2)
mobile[0:4]
# Out:
# ['4.5 out of 5 stars.',
#  '5.0 out of 5 stars.',
#  '5.0 out of 5 stars.',
#  '4.5 out of 5 stars.']

# %%
rev=driver14.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev:
    title3=i.text
    rating.append(title3)
rating[0:4]
rev1=driver14.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev1:
    title1=i.text
    rating.append(title1)
rating[0:4]
rev2=driver14.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev2:
    title2=i.text
    rating.append(title2)
rating[0:4]
rev3=driver14.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev3:
    title0=i.text
    rating.append(title0)
rating[0:4]
rev4=driver14.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev4:
    title4=i.text
    rating.append(title4)
rating[0:4]
rev5=driver14.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev5:
    title5=i.text
    rating.append(title5)
rating[0:4]
rev6=driver14.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev6:
    title6=i.text
    rating.append(title6)
rating[0:4]
rev7=driver14.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev7:
    title7=i.text
    rating.append(title7)
rating[0:4]
rev8=driver14.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev8:
    title8=i.text
    rating.append(title8)
rating[0:4]
rev9=driver14.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev9:
    title9=i.text
    rating.append(title9)
rating[0:4]
rev10=driver14.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev10:
    title31=i.text
    rating.append(title31)
rating[0:4]
rev11=driver14.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev11:
    title32=i.text
    rating.append(title32)
rating[0:4]
rev12=driver14.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev12:
    title33=i.text
    rating.append(title33)
rating[0:4]
rev13=driver14.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev13:
    title34=i.text
    rating.append(title34)
rating[0:4]
rev14=driver14.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev14:
    title35=i.text
    rating.append(title35)
rating[0:4]
rev15=driver14.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev15:
    title36=i.text
    rating.append(title36)
rating[0:4]
rev16=driver14.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev16:
    title37=i.text
    rating.append(title37)
rating[0:4]
rev17=driver14.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev17:
    title38=i.text
    rating.append(title38)
rating[0:4]
rev18=driver14.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev18:
    title39=i.text
    rating.append(title39)
rating[0:4]
rev19=driver14.find_elements_by_xpath("//span[@class='s-item__reviews-count']")
for i in rev19:
    title311=i.text
    rating.append(title311)
rating[0:4]
# Out:
# ['4 product ratings\n- 19" 5-Wire Touchscreen LCD VGA 19 inch Touch Screen Monitor POS USA Seller',
#  '5 product ratings\n- Dell 1907FPVT LCD Monitor',
#  '1 product rating\n- HP 3UA74AA 27 YH 27 inch LED Backlit IPS Monitor with 1920 x 1080 Full HD NEW',
#  '5 product ratings\n- LG 24" IPS LED FHD Monitor 1920 x 1080 FreeSync Black 24ML44B-B']

# %%
print(len(mobile),len(rating))
# Out:
# 2046 2020

# %%
rout=pd.DataFrame({})
rout['rout']=mobile[0:2020]
rout['review&rating']=rating[0:2020]

# %%
rout
# Out:
#                      rout                                      review&rating
# 0     4.5 out of 5 stars.  4 product ratings\n- 19" 5-Wire Touchscreen LC...
# 1     5.0 out of 5 stars.     5 product ratings\n- Dell 1907FPVT LCD Monitor
# 2     5.0 out of 5 stars.  1 product rating\n- HP 3UA74AA 27 YH 27 inch L...
# 3     4.5 out of 5 stars.  5 product ratings\n- LG 24" IPS LED FHD Monito...
# 4     4.0 out of 5 stars.  5 product ratings\n- LG 24" UltraGear FHD 144H...
# ...                   ...                                                ...
# 2015  4.5 out of 5 stars.  19 product ratings\n- D-Link RangeBooster N DI...
# 2016  5.0 out of 5 stars.  45 product ratings\n- NETGEAR AC1200 Smart Wi-...
# 2017  4.5 out of 5 stars.  640 product ratings\n- NETGEAR Nighthawk AC190...
# 2018  4.5 out of 5 stars.  253 product ratings\n- Cisco Linksys E1200 V2 ...
# 2019  4.5 out of 5 stars.  3 product ratings\n- 5 Bit Architectural Moldi...
#
# [2020 rows x 2 columns]

# %%
rout.to_csv("rout.csv")
